# %%
import datetime
import pandas as pd
import requests

# %%
todaysDate = datetime.datetime.now()
delta = datetime.timedelta(days=30)
newdate = todaysDate - delta
key = newdate.strftime("%Y-%b")

# %%
url = "https://api.msrc.microsoft.com/cvrf/v2.0/document/" + key
headers = {'Accept': 'application/json'}
response = requests.get(url, headers=headers)
json_data = response.json()

# %%
vulns = json_data.get('Vulnerability')
df_vulns = pd.json_normalize(vulns)
df_revisionHistory = pd.json_normalize(data=vulns, record_path=['RevisionHistory'])

# %%
df_revisionHistory
# Out:
#     Number                 Date                Description.Value
# 0      1.0  2022-04-12T07:00:00  <p>Information published.</p>\n
# 1      1.0  2022-04-12T07:00:00  <p>Information published.</p>\n
# 2      1.0  2022-04-12T07:00:00  <p>Information published.</p>\n
# 3      1.0  2022-04-12T07:00:00  <p>Information published.</p>\n
# 4      1.0  2022-04-12T08:00:00  <p>Information published.</p>\n
# ..     ...                  ...                              ...
# 181    1.0  2022-04-28T15:56:33  <p>Information published.</p>\n
# 182    1.0  2022-04-28T15:56:43  <p>Information published.</p>\n
# 183    1.0  2022-04-28T15:56:52  <p>Information published.</p>\n
# 184    1.0  2022-04-28T15:57:02  <p>Information published.</p>\n
# 185    1.0  2022-04-28T15:57:09  <p>Information published.</p>\n
#
# [186 rows x 3 columns]

# %%
df_revisionHistory.rename(columns = {'Number':'RevisionHistory.Number', 'Date':'RevisionHistory.Date','Description.Value':'RevisionHistory.Description'}, inplace = True)

# %%
df_vulns = df_vulns.join(df_revisionHistory)
pd.set_option('display.max_columns', 40)
df_vulns
# Out:
#                                                  Notes  \
# 0    [{'Title': 'Description', 'Type': 2, 'Ordinal'...
# 1    [{'Title': 'Description', 'Type': 2, 'Ordinal'...
# 2    [{'Title': 'Description', 'Type': 2, 'Ordinal'...
# 3    [{'Title': 'Description', 'Type': 2, 'Ordinal'...
# 4    [{'Title': 'Description', 'Type': 2, 'Ordinal'...
# ..                                                 ...
# 176  [{'Title': 'Description', 'Type': 2, 'Ordinal'...
# 177  [{'Title': 'Description', 'Type': 2, 'Ordinal'...
# 178  [{'Title': 'Description', 'Type': 2, 'Ordinal'...
# 179  [{'Title': 'Description', 'Type': 2, 'Ordinal'...
# 180  [{'Title': 'Description', 'Type': 2, 'Ordinal'...
#
#      DiscoveryDateSpecified  ReleaseDateSpecified             CVE  \
# 0                     False                 False  CVE-2022-22008
# 1                     False                 False  CVE-2022-22009
# 2                     False                 False  CVE-2022-21983
# 3                     False                 False  CVE-2022-23257
# 4                     False                 False  CVE-2022-23268
# ..                      ...                   ...             ...
# 176                   False                 False   CVE-2022-1497
# 177                   False                 False   CVE-2022-1498
# 178                   False                 False   CVE-2022-1499
# 179                   False                 False   CVE-2022-1500
# 180                   False                 False   CVE-2022-1501
#
#                                        ProductStatuses  \
# 0    [{'ProductID': ['11569', '11571', '11572', '11...
# 1    [{'ProductID': ['11896', '11923', '11924', '11...
# 2    [{'ProductID': ['11568', '11569', '11570', '11...
# 3    [{'ProductID': ['11896', '11923', '11924', '11...
# 4    [{'ProductID': ['11923', '11924', '11926'], 'T...
# ..                                                 ...
# 176              [{'ProductID': ['11655'], 'Type': 3}]
# 177              [{'ProductID': ['11655'], 'Type': 3}]
# 178              [{'ProductID': ['11655'], 'Type': 3}]
# 179              [{'ProductID': ['11655'], 'Type': 3}]
# 180              [{'ProductID': ['11655'], 'Type': 3}]
#
#                                                Threats  \
# 0    [{'Description': {'Value': 'Remote Code Execut...
# 1    [{'Description': {'Value': 'Remote Code Execut...
# 2    [{'Description': {'Value': 'Remote Code Execut...
# 3    [{'Description': {'Value': 'Remote Code Execut...
# 4    [{'Description': {'Value': 'Denial of Service'...
# ..                                                 ...
# 176  [{'Description': {}, 'ProductID': ['11655'], '...
# 177  [{'Description': {}, 'ProductID': ['11655'], '...
# 178  [{'Description': {}, 'ProductID': ['11655'], '...
# 179  [{'Description': {}, 'ProductID': ['11655'], '...
# 180  [{'Description': {}, 'ProductID': ['11655'], '...
#
#                                          CVSSScoreSets  \
# 0    [{'BaseScore': 7.8, 'TemporalScore': 6.8, 'Vec...
# 1    [{'BaseScore': 7.8, 'TemporalScore': 6.8, 'Vec...
# 2    [{'BaseScore': 7.5, 'TemporalScore': 6.5, 'Vec...
# 3    [{'BaseScore': 8.8, 'TemporalScore': 7.7, 'Vec...
# 4    [{'BaseScore': 6.5, 'TemporalScore': 5.7, 'Vec...
# ..                                                 ...
# 176                                                 []
# 177                                                 []
# 178                                                 []
# 179                                                 []
# 180                                                 []
#
#                                           Remediations  \
# 0    [{'Description': {'Value': '5012647'}, 'URL': ...
# 1    [{'Description': {'Value': '5012599'}, 'URL': ...
# 2    [{'Description': {'Value': '5012647'}, 'URL': ...
# 3    [{'Description': {'Value': '5012599'}, 'URL': ...
# 4    [{'Description': {'Value': '5012604'}, 'URL': ...
# ..                                                 ...
# 176  [{'Description': {'Value': 'Release Notes'}, '...
# 177  [{'Description': {'Value': 'Release Notes'}, '...
# 178  [{'Description': {'Value': 'Release Notes'}, '...
# 179  [{'Description': {'Value': 'Release Notes'}, '...
# 180  [{'Description': {'Value': 'Release Notes'}, '...
#
#                                        Acknowledgments Ordinal  \
# 0    [{'Name': [{'Value': '<a href="https://twitter...      51
# 1    [{'Name': [{'Value': '<a href="https://twitter...      52
# 2    [{'Name': [{'Value': 'Yuki Chen with <a href="...      50
# 3    [{'Name': [{'Value': '<a href="https://twitter...      53
# 4    [{'Name': [{'Value': '<a href="https://twitter...      55
# ..                                                 ...     ...
# 176                                                 []      45
# 177                                                 []      46
# 178                                                 []      47
# 179                                                 []      48
# 180                                                 []      49
#
#                                        RevisionHistory  \
# 0    [{'Number': '1.0', 'Date': '2022-04-12T07:00:0...
# 1    [{'Number': '1.0', 'Date': '2022-04-12T07:00:0...
# 2    [{'Number': '1.0', 'Date': '2022-04-12T07:00:0...
# 3    [{'Number': '1.0', 'Date': '2022-04-12T07:00:0...
# 4    [{'Number': '1.0', 'Date': '2022-04-12T08:00:0...
# ..                                                 ...
# 176  [{'Number': '1.0', 'Date': '2022-04-28T15:56:3...
# 177  [{'Number': '1.0', 'Date': '2022-04-28T15:56:4...
# 178  [{'Number': '1.0', 'Date': '2022-04-28T15:56:5...
# 179  [{'Number': '1.0', 'Date': '2022-04-28T15:57:0...
# 180  [{'Number': '1.0', 'Date': '2022-04-28T15:57:0...
#
#                                            Title.Value RevisionHistory.Number  \
# 0    Windows Hyper-V Remote Code Execution Vulnerab...                    1.0
# 1    Windows Hyper-V Remote Code Execution Vulnerab...                    1.0
# 2    Win32 Stream Enumeration Remote Code Execution...                    1.0
# 3    Windows Hyper-V Remote Code Execution Vulnerab...                    1.0
# 4      Windows Hyper-V Denial of Service Vulnerability                    1.0
# ..                                                 ...                    ...
# 176  Chromium: CVE-2022-1497 Inappropriate implemen...                    1.0
# 177  Chromium: CVE-2022-1498 Inappropriate implemen...                    1.0
# 178  Chromium: CVE-2022-1499 Inappropriate implemen...                    1.0
# 179  Chromium: CVE-2022-1500 Insufficient data vali...                    1.0
# 180  Chromium: CVE-2022-1501 Inappropriate implemen...                    1.0
#
#     RevisionHistory.Date      RevisionHistory.Description
# 0    2022-04-12T07:00:00  <p>Information published.</p>\n
# 1    2022-04-12T07:00:00  <p>Information published.</p>\n
# 2    2022-04-12T07:00:00  <p>Information published.</p>\n
# 3    2022-04-12T07:00:00  <p>Information published.</p>\n
# 4    2022-04-12T08:00:00  <p>Information published.</p>\n
# ..                   ...                              ...
# 176  2022-04-28T15:55:46  <p>Information published.</p>\n
# 177  2022-04-28T15:55:55  <p>Information published.</p>\n
# 178  2022-04-28T15:56:05  <p>Information published.</p>\n
# 179  2022-04-28T15:56:14  <p>Information published.</p>\n
# 180  2022-04-28T15:56:23  <p>Information published.</p>\n
#
# [181 rows x 15 columns]

# %%
df_vulns.drop('RevisionHistory', inplace=True, axis=1)
df_vulns
# Out:
#                                                  Notes  \
# 0    [{'Title': 'Description', 'Type': 2, 'Ordinal'...
# 1    [{'Title': 'Description', 'Type': 2, 'Ordinal'...
# 2    [{'Title': 'Description', 'Type': 2, 'Ordinal'...
# 3    [{'Title': 'Description', 'Type': 2, 'Ordinal'...
# 4    [{'Title': 'Description', 'Type': 2, 'Ordinal'...
# ..                                                 ...
# 176  [{'Title': 'Description', 'Type': 2, 'Ordinal'...
# 177  [{'Title': 'Description', 'Type': 2, 'Ordinal'...
# 178  [{'Title': 'Description', 'Type': 2, 'Ordinal'...
# 179  [{'Title': 'Description', 'Type': 2, 'Ordinal'...
# 180  [{'Title': 'Description', 'Type': 2, 'Ordinal'...
#
#      DiscoveryDateSpecified  ReleaseDateSpecified             CVE  \
# 0                     False                 False  CVE-2022-22008
# 1                     False                 False  CVE-2022-22009
# 2                     False                 False  CVE-2022-21983
# 3                     False                 False  CVE-2022-23257
# 4                     False                 False  CVE-2022-23268
# ..                      ...                   ...             ...
# 176                   False                 False   CVE-2022-1497
# 177                   False                 False   CVE-2022-1498
# 178                   False                 False   CVE-2022-1499
# 179                   False                 False   CVE-2022-1500
# 180                   False                 False   CVE-2022-1501
#
#                                        ProductStatuses  \
# 0    [{'ProductID': ['11569', '11571', '11572', '11...
# 1    [{'ProductID': ['11896', '11923', '11924', '11...
# 2    [{'ProductID': ['11568', '11569', '11570', '11...
# 3    [{'ProductID': ['11896', '11923', '11924', '11...
# 4    [{'ProductID': ['11923', '11924', '11926'], 'T...
# ..                                                 ...
# 176              [{'ProductID': ['11655'], 'Type': 3}]
# 177              [{'ProductID': ['11655'], 'Type': 3}]
# 178              [{'ProductID': ['11655'], 'Type': 3}]
# 179              [{'ProductID': ['11655'], 'Type': 3}]
# 180              [{'ProductID': ['11655'], 'Type': 3}]
#
#                                                Threats  \
# 0    [{'Description': {'Value': 'Remote Code Execut...
# 1    [{'Description': {'Value': 'Remote Code Execut...
# 2    [{'Description': {'Value': 'Remote Code Execut...
# 3    [{'Description': {'Value': 'Remote Code Execut...
# 4    [{'Description': {'Value': 'Denial of Service'...
# ..                                                 ...
# 176  [{'Description': {}, 'ProductID': ['11655'], '...
# 177  [{'Description': {}, 'ProductID': ['11655'], '...
# 178  [{'Description': {}, 'ProductID': ['11655'], '...
# 179  [{'Description': {}, 'ProductID': ['11655'], '...
# 180  [{'Description': {}, 'ProductID': ['11655'], '...
#
#                                          CVSSScoreSets  \
# 0    [{'BaseScore': 7.8, 'TemporalScore': 6.8, 'Vec...
# 1    [{'BaseScore': 7.8, 'TemporalScore': 6.8, 'Vec...
# 2    [{'BaseScore': 7.5, 'TemporalScore': 6.5, 'Vec...
# 3    [{'BaseScore': 8.8, 'TemporalScore': 7.7, 'Vec...
# 4    [{'BaseScore': 6.5, 'TemporalScore': 5.7, 'Vec...
# ..                                                 ...
# 176                                                 []
# 177                                                 []
# 178                                                 []
# 179                                                 []
# 180                                                 []
#
#                                           Remediations  \
# 0    [{'Description': {'Value': '5012647'}, 'URL': ...
# 1    [{'Description': {'Value': '5012599'}, 'URL': ...
# 2    [{'Description': {'Value': '5012647'}, 'URL': ...
# 3    [{'Description': {'Value': '5012599'}, 'URL': ...
# 4    [{'Description': {'Value': '5012604'}, 'URL': ...
# ..                                                 ...
# 176  [{'Description': {'Value': 'Release Notes'}, '...
# 177  [{'Description': {'Value': 'Release Notes'}, '...
# 178  [{'Description': {'Value': 'Release Notes'}, '...
# 179  [{'Description': {'Value': 'Release Notes'}, '...
# 180  [{'Description': {'Value': 'Release Notes'}, '...
#
#                                        Acknowledgments Ordinal  \
# 0    [{'Name': [{'Value': '<a href="https://twitter...      51
# 1    [{'Name': [{'Value': '<a href="https://twitter...      52
# 2    [{'Name': [{'Value': 'Yuki Chen with <a href="...      50
# 3    [{'Name': [{'Value': '<a href="https://twitter...      53
# 4    [{'Name': [{'Value': '<a href="https://twitter...      55
# ..                                                 ...     ...
# 176                                                 []      45
# 177                                                 []      46
# 178                                                 []      47
# 179                                                 []      48
# 180                                                 []      49
#
#                                            Title.Value RevisionHistory.Number  \
# 0    Windows Hyper-V Remote Code Execution Vulnerab...                    1.0
# 1    Windows Hyper-V Remote Code Execution Vulnerab...                    1.0
# 2    Win32 Stream Enumeration Remote Code Execution...                    1.0
# 3    Windows Hyper-V Remote Code Execution Vulnerab...                    1.0
# 4      Windows Hyper-V Denial of Service Vulnerability                    1.0
# ..                                                 ...                    ...
# 176  Chromium: CVE-2022-1497 Inappropriate implemen...                    1.0
# 177  Chromium: CVE-2022-1498 Inappropriate implemen...                    1.0
# 178  Chromium: CVE-2022-1499 Inappropriate implemen...                    1.0
# 179  Chromium: CVE-2022-1500 Insufficient data vali...                    1.0
# 180  Chromium: CVE-2022-1501 Inappropriate implemen...                    1.0
#
#     RevisionHistory.Date      RevisionHistory.Description
# 0    2022-04-12T07:00:00  <p>Information published.</p>\n
# 1    2022-04-12T07:00:00  <p>Information published.</p>\n
# 2    2022-04-12T07:00:00  <p>Information published.</p>\n
# 3    2022-04-12T07:00:00  <p>Information published.</p>\n
# 4    2022-04-12T08:00:00  <p>Information published.</p>\n
# ..                   ...                              ...
# 176  2022-04-28T15:55:46  <p>Information published.</p>\n
# 177  2022-04-28T15:55:55  <p>Information published.</p>\n
# 178  2022-04-28T15:56:05  <p>Information published.</p>\n
# 179  2022-04-28T15:56:14  <p>Information published.</p>\n
# 180  2022-04-28T15:56:23  <p>Information published.</p>\n
#
# [181 rows x 14 columns]

# %%
df_CVSSScore = pd.json_normalize(data=vulns, record_path=['CVSSScoreSets'])
df_CVSSScore
# Out:
#       BaseScore  TemporalScore  \
# 0           7.8            6.8
# 1           7.8            6.8
# 2           7.8            6.8
# 3           7.8            6.8
# 4           7.8            6.8
# ...         ...            ...
# 2951        7.3            6.4
# 2952        7.5            6.5
# 2953        7.5            6.5
# 2954        8.3            7.2
# 2955        3.1            2.8
#
#                                                  Vector ProductID
# 0     CVSS:3.1/AV:L/AC:H/PR:L/UI:N/S:C/C:H/I:H/A:H/E...   [11569]
# 1     CVSS:3.1/AV:L/AC:H/PR:L/UI:N/S:C/C:H/I:H/A:H/E...   [11571]
# 2     CVSS:3.1/AV:L/AC:H/PR:L/UI:N/S:C/C:H/I:H/A:H/E...   [11572]
# 3     CVSS:3.1/AV:L/AC:H/PR:L/UI:N/S:C/C:H/I:H/A:H/E...   [11713]
# 4     CVSS:3.1/AV:L/AC:H/PR:L/UI:N/S:C/C:H/I:H/A:H/E...   [11896]
# ...                                                 ...       ...
# 2951  CVSS:3.1/AV:L/AC:L/PR:L/UI:R/S:U/C:H/I:H/A:H/E...   [11622]
# 2952  CVSS:3.1/AV:N/AC:L/PR:N/UI:N/S:U/C:N/I:N/A:H/E...   [12029]
# 2953  CVSS:3.1/AV:N/AC:L/PR:N/UI:N/S:U/C:N/I:N/A:H/E...   [12030]
# 2954  CVSS:3.1/AV:N/AC:H/PR:N/UI:R/S:C/C:H/I:H/A:H/E...   [11655]
# 2955  CVSS:3.1/AV:N/AC:H/PR:N/UI:R/S:U/C:N/I:L/A:N/E...   [11655]
#
# [2956 rows x 4 columns]

# %%
df_CVSSScore.rename(columns = {'BaseScore':'cvssScore.BaseScore', 'TemporalScore':'cvssScore.TemporalScore','Vector':'cvssScore.Vector','ProductID':'cvssScore.ProductID'}, inplace = True)
df_CVSSScore
# Out:
#       cvssScore.BaseScore  cvssScore.TemporalScore  \
# 0                     7.8                      6.8
# 1                     7.8                      6.8
# 2                     7.8                      6.8
# 3                     7.8                      6.8
# 4                     7.8                      6.8
# ...                   ...                      ...
# 2951                  7.3                      6.4
# 2952                  7.5                      6.5
# 2953                  7.5                      6.5
# 2954                  8.3                      7.2
# 2955                  3.1                      2.8
#
#                                        cvssScore.Vector cvssScore.ProductID
# 0     CVSS:3.1/AV:L/AC:H/PR:L/UI:N/S:C/C:H/I:H/A:H/E...             [11569]
# 1     CVSS:3.1/AV:L/AC:H/PR:L/UI:N/S:C/C:H/I:H/A:H/E...             [11571]
# 2     CVSS:3.1/AV:L/AC:H/PR:L/UI:N/S:C/C:H/I:H/A:H/E...             [11572]
# 3     CVSS:3.1/AV:L/AC:H/PR:L/UI:N/S:C/C:H/I:H/A:H/E...             [11713]
# 4     CVSS:3.1/AV:L/AC:H/PR:L/UI:N/S:C/C:H/I:H/A:H/E...             [11896]
# ...                                                 ...                 ...
# 2951  CVSS:3.1/AV:L/AC:L/PR:L/UI:R/S:U/C:H/I:H/A:H/E...             [11622]
# 2952  CVSS:3.1/AV:N/AC:L/PR:N/UI:N/S:U/C:N/I:N/A:H/E...             [12029]
# 2953  CVSS:3.1/AV:N/AC:L/PR:N/UI:N/S:U/C:N/I:N/A:H/E...             [12030]
# 2954  CVSS:3.1/AV:N/AC:H/PR:N/UI:R/S:C/C:H/I:H/A:H/E...             [11655]
# 2955  CVSS:3.1/AV:N/AC:H/PR:N/UI:R/S:U/C:N/I:L/A:N/E...             [11655]
#
# [2956 rows x 4 columns]

# %%
df_vulns = df_vulns.join(df_CVSSScore)
df_vulns.drop('CVSSScoreSets', inplace=True, axis=1)
df_vulns
# Out:
#                                                  Notes  \
# 0    [{'Title': 'Description', 'Type': 2, 'Ordinal'...
# 1    [{'Title': 'Description', 'Type': 2, 'Ordinal'...
# 2    [{'Title': 'Description', 'Type': 2, 'Ordinal'...
# 3    [{'Title': 'Description', 'Type': 2, 'Ordinal'...
# 4    [{'Title': 'Description', 'Type': 2, 'Ordinal'...
# ..                                                 ...
# 176  [{'Title': 'Description', 'Type': 2, 'Ordinal'...
# 177  [{'Title': 'Description', 'Type': 2, 'Ordinal'...
# 178  [{'Title': 'Description', 'Type': 2, 'Ordinal'...
# 179  [{'Title': 'Description', 'Type': 2, 'Ordinal'...
# 180  [{'Title': 'Description', 'Type': 2, 'Ordinal'...
#
#      DiscoveryDateSpecified  ReleaseDateSpecified             CVE  \
# 0                     False                 False  CVE-2022-22008
# 1                     False                 False  CVE-2022-22009
# 2                     False                 False  CVE-2022-21983
# 3                     False                 False  CVE-2022-23257
# 4                     False                 False  CVE-2022-23268
# ..                      ...                   ...             ...
# 176                   False                 False   CVE-2022-1497
# 177                   False                 False   CVE-2022-1498
# 178                   False                 False   CVE-2022-1499
# 179                   False                 False   CVE-2022-1500
# 180                   False                 False   CVE-2022-1501
#
#                                        ProductStatuses  \
# 0    [{'ProductID': ['11569', '11571', '11572', '11...
# 1    [{'ProductID': ['11896', '11923', '11924', '11...
# 2    [{'ProductID': ['11568', '11569', '11570', '11...
# 3    [{'ProductID': ['11896', '11923', '11924', '11...
# 4    [{'ProductID': ['11923', '11924', '11926'], 'T...
# ..                                                 ...
# 176              [{'ProductID': ['11655'], 'Type': 3}]
# 177              [{'ProductID': ['11655'], 'Type': 3}]
# 178              [{'ProductID': ['11655'], 'Type': 3}]
# 179              [{'ProductID': ['11655'], 'Type': 3}]
# 180              [{'ProductID': ['11655'], 'Type': 3}]
#
#                                                Threats  \
# 0    [{'Description': {'Value': 'Remote Code Execut...
# 1    [{'Description': {'Value': 'Remote Code Execut...
# 2    [{'Description': {'Value': 'Remote Code Execut...
# 3    [{'Description': {'Value': 'Remote Code Execut...
# 4    [{'Description': {'Value': 'Denial of Service'...
# ..                                                 ...
# 176  [{'Description': {}, 'ProductID': ['11655'], '...
# 177  [{'Description': {}, 'ProductID': ['11655'], '...
# 178  [{'Description': {}, 'ProductID': ['11655'], '...
# 179  [{'Description': {}, 'ProductID': ['11655'], '...
# 180  [{'Description': {}, 'ProductID': ['11655'], '...
#
#                                           Remediations  \
# 0    [{'Description': {'Value': '5012647'}, 'URL': ...
# 1    [{'Description': {'Value': '5012599'}, 'URL': ...
# 2    [{'Description': {'Value': '5012647'}, 'URL': ...
# 3    [{'Description': {'Value': '5012599'}, 'URL': ...
# 4    [{'Description': {'Value': '5012604'}, 'URL': ...
# ..                                                 ...
# 176  [{'Description': {'Value': 'Release Notes'}, '...
# 177  [{'Description': {'Value': 'Release Notes'}, '...
# 178  [{'Description': {'Value': 'Release Notes'}, '...
# 179  [{'Description': {'Value': 'Release Notes'}, '...
# 180  [{'Description': {'Value': 'Release Notes'}, '...
#
#                                        Acknowledgments Ordinal  \
# 0    [{'Name': [{'Value': '<a href="https://twitter...      51
# 1    [{'Name': [{'Value': '<a href="https://twitter...      52
# 2    [{'Name': [{'Value': 'Yuki Chen with <a href="...      50
# 3    [{'Name': [{'Value': '<a href="https://twitter...      53
# 4    [{'Name': [{'Value': '<a href="https://twitter...      55
# ..                                                 ...     ...
# 176                                                 []      45
# 177                                                 []      46
# 178                                                 []      47
# 179                                                 []      48
# 180                                                 []      49
#
#                                            Title.Value RevisionHistory.Number  \
# 0    Windows Hyper-V Remote Code Execution Vulnerab...                    1.0
# 1    Windows Hyper-V Remote Code Execution Vulnerab...                    1.0
# 2    Win32 Stream Enumeration Remote Code Execution...                    1.0
# 3    Windows Hyper-V Remote Code Execution Vulnerab...                    1.0
# 4      Windows Hyper-V Denial of Service Vulnerability                    1.0
# ..                                                 ...                    ...
# 176  Chromium: CVE-2022-1497 Inappropriate implemen...                    1.0
# 177  Chromium: CVE-2022-1498 Inappropriate implemen...                    1.0
# 178  Chromium: CVE-2022-1499 Inappropriate implemen...                    1.0
# 179  Chromium: CVE-2022-1500 Insufficient data vali...                    1.0
# 180  Chromium: CVE-2022-1501 Inappropriate implemen...                    1.0
#
#     RevisionHistory.Date      RevisionHistory.Description  \
# 0    2022-04-12T07:00:00  <p>Information published.</p>\n
# 1    2022-04-12T07:00:00  <p>Information published.</p>\n
# 2    2022-04-12T07:00:00  <p>Information published.</p>\n
# 3    2022-04-12T07:00:00  <p>Information published.</p>\n
# 4    2022-04-12T08:00:00  <p>Information published.</p>\n
# ..                   ...                              ...
# 176  2022-04-28T15:55:46  <p>Information published.</p>\n
# 177  2022-04-28T15:55:55  <p>Information published.</p>\n
# 178  2022-04-28T15:56:05  <p>Information published.</p>\n
# 179  2022-04-28T15:56:14  <p>Information published.</p>\n
# 180  2022-04-28T15:56:23  <p>Information published.</p>\n
#
#      cvssScore.BaseScore  cvssScore.TemporalScore  \
# 0                    7.8                      6.8
# 1                    7.8                      6.8
# 2                    7.8                      6.8
# 3                    7.8                      6.8
# 4                    7.8                      6.8
# ..                   ...                      ...
# 176                  7.8                      6.8
# 177                  4.3                      3.8
# 178                  8.3                      7.2
# 179                  5.5                      4.8
# 180                  5.5                      4.8
#
#                                       cvssScore.Vector cvssScore.ProductID
# 0    CVSS:3.1/AV:L/AC:H/PR:L/UI:N/S:C/C:H/I:H/A:H/E...             [11569]
# 1    CVSS:3.1/AV:L/AC:H/PR:L/UI:N/S:C/C:H/I:H/A:H/E...             [11571]
# 2    CVSS:3.1/AV:L/AC:H/PR:L/UI:N/S:C/C:H/I:H/A:H/E...             [11572]
# 3    CVSS:3.1/AV:L/AC:H/PR:L/UI:N/S:C/C:H/I:H/A:H/E...             [11713]
# 4    CVSS:3.1/AV:L/AC:H/PR:L/UI:N/S:C/C:H/I:H/A:H/E...             [11896]
# ..                                                 ...                 ...
# 176  CVSS:3.1/AV:L/AC:L/PR:L/UI:N/S:U/C:H/I:H/A:H/E...             [10543]
# 177  CVSS:3.1/AV:N/AC:L/PR:N/UI:R/S:U/C:N/I:L/A:N/E...             [11655]
# 178  CVSS:3.1/AV:N/AC:H/PR:N/UI:R/S:C/C:H/I:H/A:H/E...             [11655]
# 179  CVSS:3.1/AV:L/AC:L/PR:L/UI:N/S:U/C:N/I:N/A:H/E...             [11571]
# 180  CVSS:3.1/AV:L/AC:L/PR:L/UI:N/S:U/C:N/I:N/A:H/E...             [11572]
#
# [181 rows x 17 columns]

# %%
df_notes = pd.json_normalize(data=vulns, record_path=['Notes'])
df_notes.rename(columns = {'Ordinal':'Notes.Ordinal', 'Type':'Notes.Type','Title':'Notes.Title','Value':'Notes.Value'}, inplace = True)
df_vulns = df_vulns.join(df_notes)
df_vulns.drop('Notes', inplace=True, axis=1)

# %%
df_vulns
# Out:
#      DiscoveryDateSpecified  ReleaseDateSpecified             CVE  \
# 0                     False                 False  CVE-2022-22008
# 1                     False                 False  CVE-2022-22009
# 2                     False                 False  CVE-2022-21983
# 3                     False                 False  CVE-2022-23257
# 4                     False                 False  CVE-2022-23268
# ..                      ...                   ...             ...
# 176                   False                 False   CVE-2022-1497
# 177                   False                 False   CVE-2022-1498
# 178                   False                 False   CVE-2022-1499
# 179                   False                 False   CVE-2022-1500
# 180                   False                 False   CVE-2022-1501
#
#                                        ProductStatuses  \
# 0    [{'ProductID': ['11569', '11571', '11572', '11...
# 1    [{'ProductID': ['11896', '11923', '11924', '11...
# 2    [{'ProductID': ['11568', '11569', '11570', '11...
# 3    [{'ProductID': ['11896', '11923', '11924', '11...
# 4    [{'ProductID': ['11923', '11924', '11926'], 'T...
# ..                                                 ...
# 176              [{'ProductID': ['11655'], 'Type': 3}]
# 177              [{'ProductID': ['11655'], 'Type': 3}]
# 178              [{'ProductID': ['11655'], 'Type': 3}]
# 179              [{'ProductID': ['11655'], 'Type': 3}]
# 180              [{'ProductID': ['11655'], 'Type': 3}]
#
#                                                Threats  \
# 0    [{'Description': {'Value': 'Remote Code Execut...
# 1    [{'Description': {'Value': 'Remote Code Execut...
# 2    [{'Description': {'Value': 'Remote Code Execut...
# 3    [{'Description': {'Value': 'Remote Code Execut...
# 4    [{'Description': {'Value': 'Denial of Service'...
# ..                                                 ...
# 176  [{'Description': {}, 'ProductID': ['11655'], '...
# 177  [{'Description': {}, 'ProductID': ['11655'], '...
# 178  [{'Description': {}, 'ProductID': ['11655'], '...
# 179  [{'Description': {}, 'ProductID': ['11655'], '...
# 180  [{'Description': {}, 'ProductID': ['11655'], '...
#
#                                           Remediations  \
# 0    [{'Description': {'Value': '5012647'}, 'URL': ...
# 1    [{'Description': {'Value': '5012599'}, 'URL': ...
# 2    [{'Description': {'Value': '5012647'}, 'URL': ...
# 3    [{'Description': {'Value': '5012599'}, 'URL': ...
# 4    [{'Description': {'Value': '5012604'}, 'URL': ...
# ..                                                 ...
# 176  [{'Description': {'Value': 'Release Notes'}, '...
# 177  [{'Description': {'Value': 'Release Notes'}, '...
# 178  [{'Description': {'Value': 'Release Notes'}, '...
# 179  [{'Description': {'Value': 'Release Notes'}, '...
# 180  [{'Description': {'Value': 'Release Notes'}, '...
#
#                                        Acknowledgments Ordinal  \
# 0    [{'Name': [{'Value': '<a href="https://twitter...      51
# 1    [{'Name': [{'Value': '<a href="https://twitter...      52
# 2    [{'Name': [{'Value': 'Yuki Chen with <a href="...      50
# 3    [{'Name': [{'Value': '<a href="https://twitter...      53
# 4    [{'Name': [{'Value': '<a href="https://twitter...      55
# ..                                                 ...     ...
# 176                                                 []      45
# 177                                                 []      46
# 178                                                 []      47
# 179                                                 []      48
# 180                                                 []      49
#
#                                            Title.Value RevisionHistory.Number  \
# 0    Windows Hyper-V Remote Code Execution Vulnerab...                    1.0
# 1    Windows Hyper-V Remote Code Execution Vulnerab...                    1.0
# 2    Win32 Stream Enumeration Remote Code Execution...                    1.0
# 3    Windows Hyper-V Remote Code Execution Vulnerab...                    1.0
# 4      Windows Hyper-V Denial of Service Vulnerability                    1.0
# ..                                                 ...                    ...
# 176  Chromium: CVE-2022-1497 Inappropriate implemen...                    1.0
# 177  Chromium: CVE-2022-1498 Inappropriate implemen...                    1.0
# 178  Chromium: CVE-2022-1499 Inappropriate implemen...                    1.0
# 179  Chromium: CVE-2022-1500 Insufficient data vali...                    1.0
# 180  Chromium: CVE-2022-1501 Inappropriate implemen...                    1.0
#
#     RevisionHistory.Date      RevisionHistory.Description  \
# 0    2022-04-12T07:00:00  <p>Information published.</p>\n
# 1    2022-04-12T07:00:00  <p>Information published.</p>\n
# 2    2022-04-12T07:00:00  <p>Information published.</p>\n
# 3    2022-04-12T07:00:00  <p>Information published.</p>\n
# 4    2022-04-12T08:00:00  <p>Information published.</p>\n
# ..                   ...                              ...
# 176  2022-04-28T15:55:46  <p>Information published.</p>\n
# 177  2022-04-28T15:55:55  <p>Information published.</p>\n
# 178  2022-04-28T15:56:05  <p>Information published.</p>\n
# 179  2022-04-28T15:56:14  <p>Information published.</p>\n
# 180  2022-04-28T15:56:23  <p>Information published.</p>\n
#
#      cvssScore.BaseScore  cvssScore.TemporalScore  \
# 0                    7.8                      6.8
# 1                    7.8                      6.8
# 2                    7.8                      6.8
# 3                    7.8                      6.8
# 4                    7.8                      6.8
# ..                   ...                      ...
# 176                  7.8                      6.8
# 177                  4.3                      3.8
# 178                  8.3                      7.2
# 179                  5.5                      4.8
# 180                  5.5                      4.8
#
#                                       cvssScore.Vector cvssScore.ProductID  \
# 0    CVSS:3.1/AV:L/AC:H/PR:L/UI:N/S:C/C:H/I:H/A:H/E...             [11569]
# 1    CVSS:3.1/AV:L/AC:H/PR:L/UI:N/S:C/C:H/I:H/A:H/E...             [11571]
# 2    CVSS:3.1/AV:L/AC:H/PR:L/UI:N/S:C/C:H/I:H/A:H/E...             [11572]
# 3    CVSS:3.1/AV:L/AC:H/PR:L/UI:N/S:C/C:H/I:H/A:H/E...             [11713]
# 4    CVSS:3.1/AV:L/AC:H/PR:L/UI:N/S:C/C:H/I:H/A:H/E...             [11896]
# ..                                                 ...                 ...
# 176  CVSS:3.1/AV:L/AC:L/PR:L/UI:N/S:U/C:H/I:H/A:H/E...             [10543]
# 177  CVSS:3.1/AV:N/AC:L/PR:N/UI:R/S:U/C:N/I:L/A:N/E...             [11655]
# 178  CVSS:3.1/AV:N/AC:H/PR:N/UI:R/S:C/C:H/I:H/A:H/E...             [11655]
# 179  CVSS:3.1/AV:L/AC:L/PR:L/UI:N/S:U/C:N/I:N/A:H/E...             [11571]
# 180  CVSS:3.1/AV:L/AC:L/PR:L/UI:N/S:U/C:N/I:N/A:H/E...             [11572]
#
#                Notes.Title  Notes.Type Notes.Ordinal  \
# 0              Description           2             0
# 1                      FAQ           4            10
# 2                      FAQ           4            10
# 3                      FAQ           4            10
# 4    Role: Windows Hyper-V           7            20
# ..                     ...         ...           ...
# 176                    FAQ           4            10
# 177    Azure Site Recovery           7            20
# 178              Microsoft           8            30
# 179            Description           2             0
# 180                    FAQ           4            10
#
#                                            Notes.Value
# 0                                                  NaN
# 1    <p><strong>According to the CVSS metric, the a...
# 2    <p><strong>According to the CVSS metric, the a...
# 3    <p><strong>According to the CVSS metric, a suc...
# 4                                Role: Windows Hyper-V
# ..                                                 ...
# 176  <p><strong>What type of information could be d...
# 177                                Azure Site Recovery
# 178                                          Microsoft
# 179                                                NaN
# 180  <p><strong>According to the CVSS metric, privi...
#
# [181 rows x 20 columns]

# %%
df_ProductStatuses = pd.json_normalize(data=vulns, record_path=['ProductStatuses'])
df_ProductStatuses.rename(columns = {'Type':'ProductStatuses.Type','ProductID':'ProductStatuses.ProductID'}, inplace = True)
df_vulns = df_vulns.join(df_ProductStatuses)
df_vulns.drop('ProductStatuses', inplace=True, axis=1)

# %%
df_vulns
# Out:
#      DiscoveryDateSpecified  ReleaseDateSpecified             CVE  \
# 0                     False                 False  CVE-2022-22008
# 1                     False                 False  CVE-2022-22009
# 2                     False                 False  CVE-2022-21983
# 3                     False                 False  CVE-2022-23257
# 4                     False                 False  CVE-2022-23268
# ..                      ...                   ...             ...
# 176                   False                 False   CVE-2022-1497
# 177                   False                 False   CVE-2022-1498
# 178                   False                 False   CVE-2022-1499
# 179                   False                 False   CVE-2022-1500
# 180                   False                 False   CVE-2022-1501
#
#                                                Threats  \
# 0    [{'Description': {'Value': 'Remote Code Execut...
# 1    [{'Description': {'Value': 'Remote Code Execut...
# 2    [{'Description': {'Value': 'Remote Code Execut...
# 3    [{'Description': {'Value': 'Remote Code Execut...
# 4    [{'Description': {'Value': 'Denial of Service'...
# ..                                                 ...
# 176  [{'Description': {}, 'ProductID': ['11655'], '...
# 177  [{'Description': {}, 'ProductID': ['11655'], '...
# 178  [{'Description': {}, 'ProductID': ['11655'], '...
# 179  [{'Description': {}, 'ProductID': ['11655'], '...
# 180  [{'Description': {}, 'ProductID': ['11655'], '...
#
#                                           Remediations  \
# 0    [{'Description': {'Value': '5012647'}, 'URL': ...
# 1    [{'Description': {'Value': '5012599'}, 'URL': ...
# 2    [{'Description': {'Value': '5012647'}, 'URL': ...
# 3    [{'Description': {'Value': '5012599'}, 'URL': ...
# 4    [{'Description': {'Value': '5012604'}, 'URL': ...
# ..                                                 ...
# 176  [{'Description': {'Value': 'Release Notes'}, '...
# 177  [{'Description': {'Value': 'Release Notes'}, '...
# 178  [{'Description': {'Value': 'Release Notes'}, '...
# 179  [{'Description': {'Value': 'Release Notes'}, '...
# 180  [{'Description': {'Value': 'Release Notes'}, '...
#
#                                        Acknowledgments Ordinal  \
# 0    [{'Name': [{'Value': '<a href="https://twitter...      51
# 1    [{'Name': [{'Value': '<a href="https://twitter...      52
# 2    [{'Name': [{'Value': 'Yuki Chen with <a href="...      50
# 3    [{'Name': [{'Value': '<a href="https://twitter...      53
# 4    [{'Name': [{'Value': '<a href="https://twitter...      55
# ..                                                 ...     ...
# 176                                                 []      45
# 177                                                 []      46
# 178                                                 []      47
# 179                                                 []      48
# 180                                                 []      49
#
#                                            Title.Value RevisionHistory.Number  \
# 0    Windows Hyper-V Remote Code Execution Vulnerab...                    1.0
# 1    Windows Hyper-V Remote Code Execution Vulnerab...                    1.0
# 2    Win32 Stream Enumeration Remote Code Execution...                    1.0
# 3    Windows Hyper-V Remote Code Execution Vulnerab...                    1.0
# 4      Windows Hyper-V Denial of Service Vulnerability                    1.0
# ..                                                 ...                    ...
# 176  Chromium: CVE-2022-1497 Inappropriate implemen...                    1.0
# 177  Chromium: CVE-2022-1498 Inappropriate implemen...                    1.0
# 178  Chromium: CVE-2022-1499 Inappropriate implemen...                    1.0
# 179  Chromium: CVE-2022-1500 Insufficient data vali...                    1.0
# 180  Chromium: CVE-2022-1501 Inappropriate implemen...                    1.0
#
#     RevisionHistory.Date      RevisionHistory.Description  \
# 0    2022-04-12T07:00:00  <p>Information published.</p>\n
# 1    2022-04-12T07:00:00  <p>Information published.</p>\n
# 2    2022-04-12T07:00:00  <p>Information published.</p>\n
# 3    2022-04-12T07:00:00  <p>Information published.</p>\n
# 4    2022-04-12T08:00:00  <p>Information published.</p>\n
# ..                   ...                              ...
# 176  2022-04-28T15:55:46  <p>Information published.</p>\n
# 177  2022-04-28T15:55:55  <p>Information published.</p>\n
# 178  2022-04-28T15:56:05  <p>Information published.</p>\n
# 179  2022-04-28T15:56:14  <p>Information published.</p>\n
# 180  2022-04-28T15:56:23  <p>Information published.</p>\n
#
#      cvssScore.BaseScore  cvssScore.TemporalScore  \
# 0                    7.8                      6.8
# 1                    7.8                      6.8
# 2                    7.8                      6.8
# 3                    7.8                      6.8
# 4                    7.8                      6.8
# ..                   ...                      ...
# 176                  7.8                      6.8
# 177                  4.3                      3.8
# 178                  8.3                      7.2
# 179                  5.5                      4.8
# 180                  5.5                      4.8
#
#                                       cvssScore.Vector cvssScore.ProductID  \
# 0    CVSS:3.1/AV:L/AC:H/PR:L/UI:N/S:C/C:H/I:H/A:H/E...             [11569]
# 1    CVSS:3.1/AV:L/AC:H/PR:L/UI:N/S:C/C:H/I:H/A:H/E...             [11571]
# 2    CVSS:3.1/AV:L/AC:H/PR:L/UI:N/S:C/C:H/I:H/A:H/E...             [11572]
# 3    CVSS:3.1/AV:L/AC:H/PR:L/UI:N/S:C/C:H/I:H/A:H/E...             [11713]
# 4    CVSS:3.1/AV:L/AC:H/PR:L/UI:N/S:C/C:H/I:H/A:H/E...             [11896]
# ..                                                 ...                 ...
# 176  CVSS:3.1/AV:L/AC:L/PR:L/UI:N/S:U/C:H/I:H/A:H/E...             [10543]
# 177  CVSS:3.1/AV:N/AC:L/PR:N/UI:R/S:U/C:N/I:L/A:N/E...             [11655]
# 178  CVSS:3.1/AV:N/AC:H/PR:N/UI:R/S:C/C:H/I:H/A:H/E...             [11655]
# 179  CVSS:3.1/AV:L/AC:L/PR:L/UI:N/S:U/C:N/I:N/A:H/E...             [11571]
# 180  CVSS:3.1/AV:L/AC:L/PR:L/UI:N/S:U/C:N/I:N/A:H/E...             [11572]
#
#                Notes.Title  Notes.Type Notes.Ordinal  \
# 0              Description           2             0
# 1                      FAQ           4            10
# 2                      FAQ           4            10
# 3                      FAQ           4            10
# 4    Role: Windows Hyper-V           7            20
# ..                     ...         ...           ...
# 176                    FAQ           4            10
# 177    Azure Site Recovery           7            20
# 178              Microsoft           8            30
# 179            Description           2             0
# 180                    FAQ           4            10
#
#                                            Notes.Value  \
# 0                                                  NaN
# 1    <p><strong>According to the CVSS metric, the a...
# 2    <p><strong>According to the CVSS metric, the a...
# 3    <p><strong>According to the CVSS metric, a suc...
# 4                                Role: Windows Hyper-V
# ..                                                 ...
# 176  <p><strong>What type of information could be d...
# 177                                Azure Site Recovery
# 178                                          Microsoft
# 179                                                NaN
# 180  <p><strong>According to the CVSS metric, privi...
#
#                              ProductStatuses.ProductID  ProductStatuses.Type
# 0    [11569, 11571, 11572, 11713, 11896, 11923, 119...                     3
# 1    [11896, 11923, 11924, 11800, 11803, 11926, 11931]                     3
# 2    [11568, 11569, 11570, 11571, 11572, 11712, 117...                     3
# 3    [11896, 11923, 11924, 11800, 11803, 11926, 11931]                     3
# 4                                [11923, 11924, 11926]                     3
# ..                                                 ...                   ...
# 176                                            [11655]                     3
# 177                                            [11655]                     3
# 178                                            [11655]                     3
# 179                                            [11655]                     3
# 180                                            [11655]                     3
#
# [181 rows x 21 columns]

# %%
df_Threats = pd.json_normalize(data=vulns, record_path=['Threats'])
df_Threats.rename(columns = {'ProductID':'Threats.ProductID', 'Type':'Threats.Type', 'Description.Value':'Threats.DescriptionValue','DateSpecified':'Threats.DateSpecified'}, inplace = True)
df_vulns = df_vulns.join(df_Threats)
df_vulns.drop('Threats', inplace=True, axis=1)

# %%
df_vulns
# Out:
#      DiscoveryDateSpecified  ReleaseDateSpecified             CVE  \
# 0                     False                 False  CVE-2022-22008
# 1                     False                 False  CVE-2022-22009
# 2                     False                 False  CVE-2022-21983
# 3                     False                 False  CVE-2022-23257
# 4                     False                 False  CVE-2022-23268
# ..                      ...                   ...             ...
# 176                   False                 False   CVE-2022-1497
# 177                   False                 False   CVE-2022-1498
# 178                   False                 False   CVE-2022-1499
# 179                   False                 False   CVE-2022-1500
# 180                   False                 False   CVE-2022-1501
#
#                                           Remediations  \
# 0    [{'Description': {'Value': '5012647'}, 'URL': ...
# 1    [{'Description': {'Value': '5012599'}, 'URL': ...
# 2    [{'Description': {'Value': '5012647'}, 'URL': ...
# 3    [{'Description': {'Value': '5012599'}, 'URL': ...
# 4    [{'Description': {'Value': '5012604'}, 'URL': ...
# ..                                                 ...
# 176  [{'Description': {'Value': 'Release Notes'}, '...
# 177  [{'Description': {'Value': 'Release Notes'}, '...
# 178  [{'Description': {'Value': 'Release Notes'}, '...
# 179  [{'Description': {'Value': 'Release Notes'}, '...
# 180  [{'Description': {'Value': 'Release Notes'}, '...
#
#                                        Acknowledgments Ordinal  \
# 0    [{'Name': [{'Value': '<a href="https://twitter...      51
# 1    [{'Name': [{'Value': '<a href="https://twitter...      52
# 2    [{'Name': [{'Value': 'Yuki Chen with <a href="...      50
# 3    [{'Name': [{'Value': '<a href="https://twitter...      53
# 4    [{'Name': [{'Value': '<a href="https://twitter...      55
# ..                                                 ...     ...
# 176                                                 []      45
# 177                                                 []      46
# 178                                                 []      47
# 179                                                 []      48
# 180                                                 []      49
#
#                                            Title.Value RevisionHistory.Number  \
# 0    Windows Hyper-V Remote Code Execution Vulnerab...                    1.0
# 1    Windows Hyper-V Remote Code Execution Vulnerab...                    1.0
# 2    Win32 Stream Enumeration Remote Code Execution...                    1.0
# 3    Windows Hyper-V Remote Code Execution Vulnerab...                    1.0
# 4      Windows Hyper-V Denial of Service Vulnerability                    1.0
# ..                                                 ...                    ...
# 176  Chromium: CVE-2022-1497 Inappropriate implemen...                    1.0
# 177  Chromium: CVE-2022-1498 Inappropriate implemen...                    1.0
# 178  Chromium: CVE-2022-1499 Inappropriate implemen...                    1.0
# 179  Chromium: CVE-2022-1500 Insufficient data vali...                    1.0
# 180  Chromium: CVE-2022-1501 Inappropriate implemen...                    1.0
#
#     RevisionHistory.Date      RevisionHistory.Description  \
# 0    2022-04-12T07:00:00  <p>Information published.</p>\n
# 1    2022-04-12T07:00:00  <p>Information published.</p>\n
# 2    2022-04-12T07:00:00  <p>Information published.</p>\n
# 3    2022-04-12T07:00:00  <p>Information published.</p>\n
# 4    2022-04-12T08:00:00  <p>Information published.</p>\n
# ..                   ...                              ...
# 176  2022-04-28T15:55:46  <p>Information published.</p>\n
# 177  2022-04-28T15:55:55  <p>Information published.</p>\n
# 178  2022-04-28T15:56:05  <p>Information published.</p>\n
# 179  2022-04-28T15:56:14  <p>Information published.</p>\n
# 180  2022-04-28T15:56:23  <p>Information published.</p>\n
#
#      cvssScore.BaseScore  cvssScore.TemporalScore  \
# 0                    7.8                      6.8
# 1                    7.8                      6.8
# 2                    7.8                      6.8
# 3                    7.8                      6.8
# 4                    7.8                      6.8
# ..                   ...                      ...
# 176                  7.8                      6.8
# 177                  4.3                      3.8
# 178                  8.3                      7.2
# 179                  5.5                      4.8
# 180                  5.5                      4.8
#
#                                       cvssScore.Vector cvssScore.ProductID  \
# 0    CVSS:3.1/AV:L/AC:H/PR:L/UI:N/S:C/C:H/I:H/A:H/E...             [11569]
# 1    CVSS:3.1/AV:L/AC:H/PR:L/UI:N/S:C/C:H/I:H/A:H/E...             [11571]
# 2    CVSS:3.1/AV:L/AC:H/PR:L/UI:N/S:C/C:H/I:H/A:H/E...             [11572]
# 3    CVSS:3.1/AV:L/AC:H/PR:L/UI:N/S:C/C:H/I:H/A:H/E...             [11713]
# 4    CVSS:3.1/AV:L/AC:H/PR:L/UI:N/S:C/C:H/I:H/A:H/E...             [11896]
# ..                                                 ...                 ...
# 176  CVSS:3.1/AV:L/AC:L/PR:L/UI:N/S:U/C:H/I:H/A:H/E...             [10543]
# 177  CVSS:3.1/AV:N/AC:L/PR:N/UI:R/S:U/C:N/I:L/A:N/E...             [11655]
# 178  CVSS:3.1/AV:N/AC:H/PR:N/UI:R/S:C/C:H/I:H/A:H/E...             [11655]
# 179  CVSS:3.1/AV:L/AC:L/PR:L/UI:N/S:U/C:N/I:N/A:H/E...             [11571]
# 180  CVSS:3.1/AV:L/AC:L/PR:L/UI:N/S:U/C:N/I:N/A:H/E...             [11572]
#
#                Notes.Title  Notes.Type Notes.Ordinal  \
# 0              Description           2             0
# 1                      FAQ           4            10
# 2                      FAQ           4            10
# 3                      FAQ           4            10
# 4    Role: Windows Hyper-V           7            20
# ..                     ...         ...           ...
# 176                    FAQ           4            10
# 177    Azure Site Recovery           7            20
# 178              Microsoft           8            30
# 179            Description           2             0
# 180                    FAQ           4            10
#
#                                            Notes.Value  \
# 0                                                  NaN
# 1    <p><strong>According to the CVSS metric, the a...
# 2    <p><strong>According to the CVSS metric, the a...
# 3    <p><strong>According to the CVSS metric, a suc...
# 4                                Role: Windows Hyper-V
# ..                                                 ...
# 176  <p><strong>What type of information could be d...
# 177                                Azure Site Recovery
# 178                                          Microsoft
# 179                                                NaN
# 180  <p><strong>According to the CVSS metric, privi...
#
#                              ProductStatuses.ProductID  ProductStatuses.Type  \
# 0    [11569, 11571, 11572, 11713, 11896, 11923, 119...                     3
# 1    [11896, 11923, 11924, 11800, 11803, 11926, 11931]                     3
# 2    [11568, 11569, 11570, 11571, 11572, 11712, 117...                     3
# 3    [11896, 11923, 11924, 11800, 11803, 11926, 11931]                     3
# 4                                [11923, 11924, 11926]                     3
# ..                                                 ...                   ...
# 176                                            [11655]                     3
# 177                                            [11655]                     3
# 178                                            [11655]                     3
# 179                                            [11655]                     3
# 180                                            [11655]                     3
#
#     Threats.ProductID  Threats.Type  Threats.DateSpecified  \
# 0             [11569]             0                  False
# 1             [11571]             0                  False
# 2             [11572]             0                  False
# 3             [11713]             0                  False
# 4             [11896]             0                  False
# ..                ...           ...                    ...
# 176           [11969]             3                  False
# 177           [12020]             3                  False
# 178               NaN             1                  False
# 179           [11568]             0                  False
# 180           [11569]             0                  False
#
#                               Threats.DescriptionValue
# 0                                Remote Code Execution
# 1                                Remote Code Execution
# 2                                Remote Code Execution
# 3                                Remote Code Execution
# 4                                Remote Code Execution
# ..                                                 ...
# 176                                          Important
# 177                                          Important
# 178  Publicly Disclosed:No;Exploited:No;Latest Soft...
# 179                             Elevation of Privilege
# 180                             Elevation of Privilege
#
# [181 rows x 24 columns]

# %%
df_Remediations = pd.json_normalize(data=vulns, record_path=['Remediations'])
df_Remediations
# Out:
#                                                     URL Supercedence  \
# 0     https://catalog.update.microsoft.com/v7/site/S...      5011503
# 1            https://support.microsoft.com/help/5012647          NaN
# 2     https://catalog.update.microsoft.com/v7/site/S...      5011485
# 3            https://support.microsoft.com/help/5012591          NaN
# 4     https://catalog.update.microsoft.com/v7/site/S...      5011487
# ...                                                 ...          ...
# 2579                                                             NaN
# 2580                                                             NaN
# 2581                                                             NaN
# 2582                                                             NaN
# 2583                                                             NaN
#
#                   ProductID  Type  DateSpecified AffectedFiles  \
# 0     [11569, 11571, 11572]     2          False            []
# 1     [11569, 11571, 11572]     5          False            []
# 2                   [11713]     2          False            []
# 3                   [11713]     5          False            []
# 4                   [11896]     2          False            []
# ...                     ...   ...            ...           ...
# 2579                [11655]     2          False            []
# 2580                [11655]     2          False            []
# 2581                [11655]     2          False            []
# 2582                [11655]     2          False            []
# 2583                [11655]     2          False            []
#
#               SubType       FixedBuild Description.Value RestartRequired.Value
# 0     Security Update  10.0.17763.2803           5012647                   Yes
# 1                 NaN              NaN           5012647                   NaN
# 2     Security Update  10.0.18363.2212           5012591                   Yes
# 3                 NaN              NaN           5012591                   NaN
# 4     Security Update  10.0.19043.1645           5012599                   Yes
# ...               ...              ...               ...                   ...
# 2579  Security Update    101.0.1210.32     Release Notes                    No
# 2580  Security Update    101.0.1210.32     Release Notes                    No
# 2581  Security Update    101.0.1210.32     Release Notes                    No
# 2582  Security Update    101.0.1210.32     Release Notes                    No
# 2583  Security Update    101.0.1210.32     Release Notes                    No
#
# [2584 rows x 10 columns]

# %%
df_Remediations.rename(columns = {'URL':'Remediations.URL', 'Supercedence':'Remediations.Supercedence', 'ProductID':'Remediations.ProductID','Type':'Remediations.Type','Description.Value':'Remediations.DescriptionValue','DateSpecified':'Remediations.DateSpecified','AffectedFiles':'Remediations.AffectedFiles','SubType':'Remediations.SubType','FixedBuild':'Remediations.FixedBuild','RestartRequired.Value':'Remediations.RestartRequired'}, inplace = True)
df_Remediations
# Out:
#                                        Remediations.URL  \
# 0     https://catalog.update.microsoft.com/v7/site/S...
# 1            https://support.microsoft.com/help/5012647
# 2     https://catalog.update.microsoft.com/v7/site/S...
# 3            https://support.microsoft.com/help/5012591
# 4     https://catalog.update.microsoft.com/v7/site/S...
# ...                                                 ...
# 2579
# 2580
# 2581
# 2582
# 2583
#
#      Remediations.Supercedence Remediations.ProductID  Remediations.Type  \
# 0                      5011503  [11569, 11571, 11572]                  2
# 1                          NaN  [11569, 11571, 11572]                  5
# 2                      5011485                [11713]                  2
# 3                          NaN                [11713]                  5
# 4                      5011487                [11896]                  2
# ...                        ...                    ...                ...
# 2579                       NaN                [11655]                  2
# 2580                       NaN                [11655]                  2
# 2581                       NaN                [11655]                  2
# 2582                       NaN                [11655]                  2
# 2583                       NaN                [11655]                  2
#
#       Remediations.DateSpecified Remediations.AffectedFiles  \
# 0                          False                         []
# 1                          False                         []
# 2                          False                         []
# 3                          False                         []
# 4                          False                         []
# ...                          ...                        ...
# 2579                       False                         []
# 2580                       False                         []
# 2581                       False                         []
# 2582                       False                         []
# 2583                       False                         []
#
#      Remediations.SubType Remediations.FixedBuild  \
# 0         Security Update         10.0.17763.2803
# 1                     NaN                     NaN
# 2         Security Update         10.0.18363.2212
# 3                     NaN                     NaN
# 4         Security Update         10.0.19043.1645
# ...                   ...                     ...
# 2579      Security Update           101.0.1210.32
# 2580      Security Update           101.0.1210.32
# 2581      Security Update           101.0.1210.32
# 2582      Security Update           101.0.1210.32
# 2583      Security Update           101.0.1210.32
#
#      Remediations.DescriptionValue Remediations.RestartRequired
# 0                          5012647                          Yes
# 1                          5012647                          NaN
# 2                          5012591                          Yes
# 3                          5012591                          NaN
# 4                          5012599                          Yes
# ...                            ...                          ...
# 2579                 Release Notes                           No
# 2580                 Release Notes                           No
# 2581                 Release Notes                           No
# 2582                 Release Notes                           No
# 2583                 Release Notes                           No
#
# [2584 rows x 10 columns]

# %%
df_vulns = df_vulns.join(df_Remediations)
df_vulns.drop('Remediations', inplace=True, axis=1)
df_vulns
# Out:
#      DiscoveryDateSpecified  ReleaseDateSpecified             CVE  \
# 0                     False                 False  CVE-2022-22008
# 1                     False                 False  CVE-2022-22009
# 2                     False                 False  CVE-2022-21983
# 3                     False                 False  CVE-2022-23257
# 4                     False                 False  CVE-2022-23268
# ..                      ...                   ...             ...
# 176                   False                 False   CVE-2022-1497
# 177                   False                 False   CVE-2022-1498
# 178                   False                 False   CVE-2022-1499
# 179                   False                 False   CVE-2022-1500
# 180                   False                 False   CVE-2022-1501
#
#                                        Acknowledgments Ordinal  \
# 0    [{'Name': [{'Value': '<a href="https://twitter...      51
# 1    [{'Name': [{'Value': '<a href="https://twitter...      52
# 2    [{'Name': [{'Value': 'Yuki Chen with <a href="...      50
# 3    [{'Name': [{'Value': '<a href="https://twitter...      53
# 4    [{'Name': [{'Value': '<a href="https://twitter...      55
# ..                                                 ...     ...
# 176                                                 []      45
# 177                                                 []      46
# 178                                                 []      47
# 179                                                 []      48
# 180                                                 []      49
#
#                                            Title.Value RevisionHistory.Number  \
# 0    Windows Hyper-V Remote Code Execution Vulnerab...                    1.0
# 1    Windows Hyper-V Remote Code Execution Vulnerab...                    1.0
# 2    Win32 Stream Enumeration Remote Code Execution...                    1.0
# 3    Windows Hyper-V Remote Code Execution Vulnerab...                    1.0
# 4      Windows Hyper-V Denial of Service Vulnerability                    1.0
# ..                                                 ...                    ...
# 176  Chromium: CVE-2022-1497 Inappropriate implemen...                    1.0
# 177  Chromium: CVE-2022-1498 Inappropriate implemen...                    1.0
# 178  Chromium: CVE-2022-1499 Inappropriate implemen...                    1.0
# 179  Chromium: CVE-2022-1500 Insufficient data vali...                    1.0
# 180  Chromium: CVE-2022-1501 Inappropriate implemen...                    1.0
#
#     RevisionHistory.Date      RevisionHistory.Description  \
# 0    2022-04-12T07:00:00  <p>Information published.</p>\n
# 1    2022-04-12T07:00:00  <p>Information published.</p>\n
# 2    2022-04-12T07:00:00  <p>Information published.</p>\n
# 3    2022-04-12T07:00:00  <p>Information published.</p>\n
# 4    2022-04-12T08:00:00  <p>Information published.</p>\n
# ..                   ...                              ...
# 176  2022-04-28T15:55:46  <p>Information published.</p>\n
# 177  2022-04-28T15:55:55  <p>Information published.</p>\n
# 178  2022-04-28T15:56:05  <p>Information published.</p>\n
# 179  2022-04-28T15:56:14  <p>Information published.</p>\n
# 180  2022-04-28T15:56:23  <p>Information published.</p>\n
#
#      cvssScore.BaseScore  cvssScore.TemporalScore  \
# 0                    7.8                      6.8
# 1                    7.8                      6.8
# 2                    7.8                      6.8
# 3                    7.8                      6.8
# 4                    7.8                      6.8
# ..                   ...                      ...
# 176                  7.8                      6.8
# 177                  4.3                      3.8
# 178                  8.3                      7.2
# 179                  5.5                      4.8
# 180                  5.5                      4.8
#
#                                       cvssScore.Vector cvssScore.ProductID  \
# 0    CVSS:3.1/AV:L/AC:H/PR:L/UI:N/S:C/C:H/I:H/A:H/E...             [11569]
# 1    CVSS:3.1/AV:L/AC:H/PR:L/UI:N/S:C/C:H/I:H/A:H/E...             [11571]
# 2    CVSS:3.1/AV:L/AC:H/PR:L/UI:N/S:C/C:H/I:H/A:H/E...             [11572]
# 3    CVSS:3.1/AV:L/AC:H/PR:L/UI:N/S:C/C:H/I:H/A:H/E...             [11713]
# 4    CVSS:3.1/AV:L/AC:H/PR:L/UI:N/S:C/C:H/I:H/A:H/E...             [11896]
# ..                                                 ...                 ...
# 176  CVSS:3.1/AV:L/AC:L/PR:L/UI:N/S:U/C:H/I:H/A:H/E...             [10543]
# 177  CVSS:3.1/AV:N/AC:L/PR:N/UI:R/S:U/C:N/I:L/A:N/E...             [11655]
# 178  CVSS:3.1/AV:N/AC:H/PR:N/UI:R/S:C/C:H/I:H/A:H/E...             [11655]
# 179  CVSS:3.1/AV:L/AC:L/PR:L/UI:N/S:U/C:N/I:N/A:H/E...             [11571]
# 180  CVSS:3.1/AV:L/AC:L/PR:L/UI:N/S:U/C:N/I:N/A:H/E...             [11572]
#
#                Notes.Title  Notes.Type Notes.Ordinal  \
# 0              Description           2             0
# 1                      FAQ           4            10
# 2                      FAQ           4            10
# 3                      FAQ           4            10
# 4    Role: Windows Hyper-V           7            20
# ..                     ...         ...           ...
# 176                    FAQ           4            10
# 177    Azure Site Recovery           7            20
# 178              Microsoft           8            30
# 179            Description           2             0
# 180                    FAQ           4            10
#
#                                            Notes.Value  \
# 0                                                  NaN
# 1    <p><strong>According to the CVSS metric, the a...
# 2    <p><strong>According to the CVSS metric, the a...
# 3    <p><strong>According to the CVSS metric, a suc...
# 4                                Role: Windows Hyper-V
# ..                                                 ...
# 176  <p><strong>What type of information could be d...
# 177                                Azure Site Recovery
# 178                                          Microsoft
# 179                                                NaN
# 180  <p><strong>According to the CVSS metric, privi...
#
#                              ProductStatuses.ProductID  ProductStatuses.Type  \
# 0    [11569, 11571, 11572, 11713, 11896, 11923, 119...                     3
# 1    [11896, 11923, 11924, 11800, 11803, 11926, 11931]                     3
# 2    [11568, 11569, 11570, 11571, 11572, 11712, 117...                     3
# 3    [11896, 11923, 11924, 11800, 11803, 11926, 11931]                     3
# 4                                [11923, 11924, 11926]                     3
# ..                                                 ...                   ...
# 176                                            [11655]                     3
# 177                                            [11655]                     3
# 178                                            [11655]                     3
# 179                                            [11655]                     3
# 180                                            [11655]                     3
#
#     Threats.ProductID  Threats.Type  Threats.DateSpecified  \
# 0             [11569]             0                  False
# 1             [11571]             0                  False
# 2             [11572]             0                  False
# 3             [11713]             0                  False
# 4             [11896]             0                  False
# ..                ...           ...                    ...
# 176           [11969]             3                  False
# 177           [12020]             3                  False
# 178               NaN             1                  False
# 179           [11568]             0                  False
# 180           [11569]             0                  False
#
#                               Threats.DescriptionValue  \
# 0                                Remote Code Execution
# 1                                Remote Code Execution
# 2                                Remote Code Execution
# 3                                Remote Code Execution
# 4                                Remote Code Execution
# ..                                                 ...
# 176                                          Important
# 177                                          Important
# 178  Publicly Disclosed:No;Exploited:No;Latest Soft...
# 179                             Elevation of Privilege
# 180                             Elevation of Privilege
#
#                                       Remediations.URL  \
# 0    https://catalog.update.microsoft.com/v7/site/S...
# 1           https://support.microsoft.com/help/5012647
# 2    https://catalog.update.microsoft.com/v7/site/S...
# 3           https://support.microsoft.com/help/5012591
# 4    https://catalog.update.microsoft.com/v7/site/S...
# ..                                                 ...
# 176         https://support.microsoft.com/help/5012650
# 177  https://catalog.update.microsoft.com/v7/site/S...
# 178         https://support.microsoft.com/help/5012666
# 179  https://catalog.update.microsoft.com/v7/site/S...
# 180         https://support.microsoft.com/help/5012670
#
#     Remediations.Supercedence Remediations.ProductID  Remediations.Type  \
# 0                     5011503  [11569, 11571, 11572]                  2
# 1                         NaN  [11569, 11571, 11572]                  5
# 2                     5011485                [11713]                  2
# 3                         NaN                [11713]                  5
# 4                     5011487                [11896]                  2
# ..                        ...                    ...                ...
# 176                       NaN         [10378, 10379]                  5
# 177                       NaN         [10378, 10379]                  2
# 178                       NaN         [10378, 10379]                  5
# 179                   5011564         [10483, 10543]                  2
# 180                       NaN         [10483, 10543]                  5
#
#      Remediations.DateSpecified Remediations.AffectedFiles  \
# 0                         False                         []
# 1                         False                         []
# 2                         False                         []
# 3                         False                         []
# 4                         False                         []
# ..                          ...                        ...
# 176                       False                         []
# 177                       False                         []
# 178                       False                         []
# 179                       False                         []
# 180                       False                         []
#
#     Remediations.SubType Remediations.FixedBuild  \
# 0        Security Update         10.0.17763.2803
# 1                    NaN                     NaN
# 2        Security Update         10.0.18363.2212
# 3                    NaN                     NaN
# 4        Security Update         10.0.19043.1645
# ..                   ...                     ...
# 176                  NaN                     NaN
# 177        Security Only          6.2.9200.23679
# 178                  NaN                     NaN
# 179       Monthly Rollup          6.3.9600.20337
# 180                  NaN                     NaN
#
#     Remediations.DescriptionValue Remediations.RestartRequired
# 0                         5012647                          Yes
# 1                         5012647                          NaN
# 2                         5012591                          Yes
# 3                         5012591                          NaN
# 4                         5012599                          Yes
# ..                            ...                          ...
# 176                       5012650                          NaN
# 177                       5012666                          Yes
# 178                       5012666                          NaN
# 179                       5012670                          Yes
# 180                       5012670                          NaN
#
# [181 rows x 33 columns]

# %%
df_Acknowledgments = pd.json_normalize(data=vulns, record_path=['Acknowledgments'])
df_Acknowledgments
# Out:
#                                                   Name URL
# 0    [{'Value': '<a href="https://twitter.com/rezer...  []
# 1    [{'Value': '<a href="https://twitter.com/rezer...  []
# 2    [{'Value': 'Yuki Chen with <a href="https://ww...  []
# 3    [{'Value': '<a href="https://twitter.com/rezer...  []
# 4    [{'Value': '<a href="https://twitter.com/rezer...  []
# ..                                                 ...  ..
# 121  [{'Value': '<a href="https://twitter.com/rskvp...  []
# 122  [{'Value': '<a href="https://www.daviderceg.co...  []
# 123  [{'Value': 's7331 with <a href="https://contro...  []
# 124  [{'Value': '<a href="https://www.daviderceg.co...  []
# 125                           [{'Value': 'Anonymous'}]  []
#
# [126 rows x 2 columns]

# %%
df_Acknowledgments_Names = df_Acknowledgments['Name']
df_Acknowledgments_Names
# Out:
# 0      [{'Value': '<a href="https://twitter.com/rezer...
# 1      [{'Value': '<a href="https://twitter.com/rezer...
# 2      [{'Value': 'Yuki Chen with <a href="https://ww...
# 3      [{'Value': '<a href="https://twitter.com/rezer...
# 4      [{'Value': '<a href="https://twitter.com/rezer...
#                              ...
# 121    [{'Value': '<a href="https://twitter.com/rskvp...
# 122    [{'Value': '<a href="https://www.daviderceg.co...
# 123    [{'Value': 's7331 with <a href="https://contro...
# 124    [{'Value': '<a href="https://www.daviderceg.co...
# 125                             [{'Value': 'Anonymous'}]
# Name: Name, Length: 126, dtype: object

# %%
df_Acknowledgments_URL = df_Acknowledgments['URL']
df_Acknowledgments_URL
# Out:
# 0      []
# 1      []
# 2      []
# 3      []
# 4      []
#        ..
# 121    []
# 122    []
# 123    []
# 124    []
# 125    []
# Name: URL, Length: 126, dtype: object

# %%
df_Acknowledgments_Names.info()
# Out:
# <class 'pandas.core.series.Series'>
# RangeIndex: 126 entries, 0 to 125
# Series name: Name
# Non-Null Count  Dtype
# --------------  -----
# 126 non-null    object
# dtypes: object(1)
# memory usage: 1.1+ KB

# %%
for value in df_Acknowledgments_Names:
    print(value)
# Out:
# [{'Value': '<a href="https://twitter.com/rezer0dai">rezer0dai</a> with Independent Slavic Voyage'}]
# [{'Value': '<a href="https://twitter.com/rezer0dai">rezer0dai</a> with NoBananas NoBugzz'}]
# [{'Value': 'Yuki Chen with <a href="https://www.cyberkl.com/">Cyber KunLun</a>'}]
# [{'Value': '<a href="https://twitter.com/rezer0dai">rezer0dai</a> with Capo di Frutti'}]
# [{'Value': '<a href="https://twitter.com/rezer0dai">PETER HLAVATY</a> with Banana Mode'}]
# [{'Value': 'Nils Ole\xa0 Timm (@firzen14) working with <a href="https://www.zerodayinitiative.com/">Trend Micro Zero Day Initiative</a>'}]
# [{'Value': 'Adam Podlosky and Amir Bazine of <a href="https://www.crowdstrike.com/">Crowdstrike</a>'}]
# [{'Value': 'National Security Agency'}]
# [{'Value': 'Anonymous Finder'}]
# [{'Value': '<a href="https://twitter.com/b2ahex">RyeLv(@b2ahex)</a>'}]
# [{'Value': '<a href="https://hackerone.com/shadow2639">MOHIT RAJ</a>'}]
# [{'Value': '<a href="https://www.daviderceg.com/">David Erceg</a>'}]
# [{'Value': 'k0shl with Kunlun Lab'}]
# [{'Value': '<a href="https://github.com/gabriel-sztejnworcel">Gabriel Sztejnworcel</a> with <a href="https://labs.cyberark.com">CyberArk</a> '}]
# [{'Value': 'Yuki Chen with <a href="https://www.cyberkl.com/">Cyber KunLun</a>'}]
# [{'Value': 'Yuki Chen with <a href="https://www.cyberkl.com/">Cyber KunLun</a>'}]
# [{'Value': 'Microsoft Offensive Research & Security Engineering (MORSE)'}]
# [{'Value': 'Microsoft Offensive Research & Security Engineering (MORSE)'}]
# [{'Value': 'Microsoft Offensive Research & Security Engineering (MORSE)'}]
# [{'Value': 'James Forshaw of Google Project Zero'}]
# [{'Value': 'Microsoft Offensive Research & Security Engineering (MORSE)'}]
# [{'Value': 'Daejin Lee, Seunghoe Kim, Donguk Kim of S2W Inc.'}]
# [{'Value': 'AppModel Deployment (DXP)'}]
# [{'Value': 'Yuki Chen with <a href="https://www.cyberkl.com/">Cyber KunLun</a>'}]
# [{'Value': 'Simon Zuckerbraun of Trend Micro Zero Day Initiative'}]
# [{'Value': 'Microsoft Offensive Research & Security Engineering (MORSE)'}]
# [{'Value': 'Microsoft Offensive Research & Security Engineering (MORSE)'}]
# [{'Value': '<a href="https://twitter.com/zashraf1337">Zubair Ashraf</a> with <a href="https://crowdstrike.com/">Crowdstrike</a>'}]
# [{'Value': '<a href="https://www.linkedin.com/in/firoozakbari/">Firooz Akbari</a> of <a href="https://vmware.com/">VMware</a>'}]
# [{'Value': '<a href="https://www.linkedin.com/in/matteborg82/">Mattias Borg</a> and <a href="https://www.linkedin.com/in/stefanschorling/">Stefan Schörling</a> with <a href="https://www.onevinn.com/">Onevinn AB</a>'}]
# [{'Value': 'Microsoft Offensive Research & Security Engineering (MORSE)'}]
# [{'Value': 'Microsoft Offensive Research & Security Engineering (MORSE)'}]
# [{'Value': 'Microsoft Offensive Research & Security Engineering (MORSE)'}]
# [{'Value': 'Microsoft Offensive Research & Security Engineering (MORSE)'}]
# [{'Value': 'Microsoft Offensive Research & Security Engineering (MORSE)'}]
# [{'Value': 'Microsoft Offensive Research & Security Engineering (MORSE)'}]
# [{'Value': 'Microsoft Offensive Research & Security Engineering (MORSE)'}]
# [{'Value': 'Microsoft Offensive Research & Security Engineering (MORSE)'}]
# [{'Value': 'Microsoft Offensive Research & Security Engineering (MORSE)'}]
# [{'Value': 'Microsoft Offensive Research & Security Engineering (MORSE)'}]
# [{'Value': '<a href="https://twitter.com/guhe120">Yuki Chen</a>'}]
# [{'Value': '<a href="https://twitter.com/guhe120">Yuki Chen</a>'}]
# [{'Value': '<a href="https://twitter.com/guhe120">Yuki Chen</a>'}]
# [{'Value': '<a href="https://www.daviderceg.com/">David Erceg</a>'}]
# [{'Value': '<a href="https://www.daviderceg.com/">David Erceg</a>'}]
# [{'Value': '<a href="https://www.daviderceg.com/">David Erceg</a>'}]
# [{'Value': '<a href="https://twitter.com/kwsecu">William S&#246;derberg</a> with <a href="https://www.f-secure.com/">F-Secure</a>'}]
# [{'Value': '<a href="https://twitter.com/kwsecu">William S&#246;derberg</a> with <a href="https://www.f-secure.com/">F-Secure</a>'}]
# [{'Value': 'William S&#246;derberg with <a href="https://www.f-secure.com/">F-Secure</a>'}]
# [{'Value': 'Pasi Saarinen with <a href="https://www.f-secure.com/">F-Secure</a>'}]
# [{'Value': '<a href="https://www.daviderceg.com/">David Erceg</a>'}]
# [{'Value': 'kdot working with <a href="https://www.zerodayinitiative.com/">Trend Micro Zero Day Initiative</a>'}]
# [{'Value': 'KLINIX5'}]
# [{'Value': 'Anonymous'}]
# [{'Value': '<a href=https://www.youtube.com/watch?v=0AhPC_dHkHo>Polar Bear</a>'}]
# [{'Value': '<a href="https://www.cyber.gc.ca/">Canadian Centre for Cyber Security</a>'}]
# [{'Value': '<a href="https://www.cyber.gc.ca/">Canadian Centre for Cyber Security</a>'}]
# [{'Value': '<a href="https://www.cyber.gc.ca/">Canadian Centre for Cyber Security</a>'}]
# [{'Value': '<a href="https://twitter.com/guhe120">Yuki Chen</a> with <a href="https://www.cyberkl.com/">Cyber KunLun</a>'}]
# [{'Value': 'namnp from Viettel Cyber Security'}]
# [{'Value': '<a href="https://www.daviderceg.com/">David Erceg</a>'}]
# [{'Value': '<a href="https://www.linkedin.com/in/fabian-schmidt-42-/">Fabian Schmidt</a>'}]
# [{'Value': 'Jake Baines with <a href="https://www.rapid7.com/">Rapid7</a>'}]
# [{'Value': "JeongOh Kyea of THEORI working with Trend Micro's Zero Day Initiative"}]
# [{'Value': '<a href="https://twitter.com/guhe120">Yuki Chen</a> with <a href="https://www.cyberkl.com/">Cyber KunLun</a>'}]
# [{'Value': '<a href="https://twitter.com/jq0904">Jinquan</a> with <a href="https://ti.dbappsecurity.com.cn/">DBAPPSecurity Threat Intelligence Center</a>'}]
# [{'Value': 'Jarvis_1oop'}]
# [{'Value': 'Dhanesh Kizhakkinan with Mandiant'}]
# [{'Value': '<a href="https://twitter.com/waleedassar">Walied Assar</a>'}]
# [{'Value': 'Microsoft Offensive Research & Security Engineering (MORSE)'}]
# [{'Value': '<a href="https://twitter.com/ecthr0s">George Hughey</a> with MSRC Vulnerabilities and Mitigations'}]
# [{'Value': 'Microsoft Offensive Research & Security Engineering (MORSE)'}]
# [{'Value': 'k0shl with Kunlun Lab'}]
# [{'Value': 'k0shl with Kunlun Lab'}]
# [{'Value': 'k0shl with Kunlun Lab'}]
# [{'Value': 'k0shl with Kunlun Lab'}]
# [{'Value': 'liubenjin with Codesafe Team of Legendsec at Qi&#39;anxin Group'}]
# [{'Value': 'Anonymous'}]
# [{'Value': '<a href="https://twitter.com/guhe120">Yuki Chen</a> with <a href="https://www.cyberkl.com/">Cyber KunLun</a>'}]
# [{'Value': '<a href="https://twitter.com/guhe120">Yuki Chen</a> with <a href="https://www.cyberkl.com/">Cyber KunLun</a>'}]
# [{'Value': '<a href="https://twitter.com/b2ahex">RyeLv (@b2ahex)</a>'}]
# [{'Value': 'Marcin Wiazowski working with <a href="https://www.zerodayinitiative.com/">Trend Micro Zero Day Initiative</a>'}]
# [{'Value': 'Marcin Wiazowski working with <a href="https://www.zerodayinitiative.com/">Trend Micro Zero Day Initiative</a>'}]
# [{'Value': 'Victor Portal with Deloitte Spain'}]
# [{'Value': '<a href="https://twitter.com/onnoveath">JaeHeng Yoon(@onnoveath)</a> with JENBlack Soft'}]
# [{'Value': '<a href="https://twitter.com/l33d0hyun">DoHyun Lee(@l33d0hyun)</a> with DNSLab, Korea University'}]
# [{'Value': '<a href="https://twitter.com/SeungYun_Le2">SeungYun LEE(@SeungYun_Le2)</a>'}]
# [{'Value': '<a href="https://twitter.com/4zure9">Azure Yang</a> with <a href="http://www.cyberkl.com/">Kunlun Lab</a>'}]
# [{'Value': '<a href="https://twitter.com/guhe120">Yuki Chen</a> with <a href="https://www.cyberkl.com/">Cyber KunLun</a>'}]
# [{'Value': '<a href="https://twitter.com/hillstone_lab">He YiSheng, Zhang WangJunJie, Li WenYue</a> with <a href="https://www.hillstonenet.com.cn/">Hillstone Network Security Research Institute</a>'}]
# [{'Value': 'liubenjin with Codesafe Team of Legendsec at Qi&#39;anxin Group'}]
# [{'Value': 'JIWO Technology Co., Ltd'}]
# [{'Value': '<a href="https://twitter.com/lxf02942370">Xuefeng Li</a> and <a href="https://twitter.com/edwardzpeng">Zhiniang Peng</a> with <a href="https://www.sangfor.com/">Sangfor</a>'}]
# [{'Value': 'JeongOh Kyea of THEORI working with <a href="https://www.zerodayinitiative.com/">Trend Micro Zero Day Initiative</a>'}]
# [{'Value': 'k0shl with Kunlun Lab'}]
# [{'Value': 'k0shl with Kunlun Lab'}]
# [{'Value': 'k0shl with Kunlun Lab'}]
# [{'Value': '<a href="https://twitter.com/ecthr0s">George Hughey</a> with MSRC Vulnerabilities and Mitigations'}]
# [{'Value': '<a href="https://twitter.com/ecthr0s">George Hughey</a> with MSRC Vulnerabilities and Mitigations'}]
# [{'Value': '<a href="https://twitter.com/ecthr0s">George Hughey</a> with MSRC Vulnerabilities and Mitigations'}]
# [{'Value': 'BugHunter010 (@CyberKunlun)'}]
# [{'Value': 'k0shl with Kunlun Lab'}]
# [{'Value': 'Yuki Chen with <a href="https://www.cyberkl.com/">Cyber KunLun</a>'}]
# [{'Value': '<a href="https://twitter.com/guhe120">Yuki Chen</a>'}]
# [{'Value': '<a href="https://twitter.com/guhe120">Yuki Chen</a>'}]
# [{'Value': '<a href="https://twitter.com/guhe120">Yuki Chen</a>'}]
# [{'Value': '<a href="https://twitter.com/guhe120">Yuki Chen</a>'}]
# [{'Value': '<a href="https://twitter.com/guhe120">Yuki Chen</a>'}]
# [{'Value': '<a href="https://twitter.com/guhe120">Yuki Chen</a>'}]
# [{'Value': '<a href="https://twitter.com/guhe120">Yuki Chen</a>'}]
# [{'Value': '<a href="https://twitter.com/guhe120">Yuki Chen</a>'}]
# [{'Value': '<a href="https://twitter.com/guhe120">Yuki Chen</a>'}]
# [{'Value': '<a href="https://twitter.com/guhe120">Yuki Chen</a>'}]
# [{'Value': '<a href="https://twitter.com/guhe120">Yuki Chen</a> '}]
# [{'Value': 'Yuki Chen with <a href="https://www.cyberkl.com/">Cyber KunLun</a>'}]
# [{'Value': '<a href="https://twitter.com/orange_8361">Orange Tsai (@orange_8361)</a> with <a href="https://devco.re/">DEVCORE</a>'}]
# [{'Value': 'Li Shuang and willJ of vulnerability research institute'}]
# [{}]
# [{'Value': '<a href="https://www.daviderceg.com/">David Erceg</a>'}]
# [{'Value': '<a href="https://www.daviderceg.com/">David Erceg</a>'}]
# [{'Value': '<a href="https://twitter.com/rskvp93">rskvp93</a> with <a href="https://lab.viettelcybersecurity.com/">VCSLAB of Viettel Cyber Security</a>'}]
# [{'Value': '<a href="https://twitter.com/rskvp93">rskvp93</a> with <a href="https://lab.viettelcybersecurity.com/">VCSLAB of Viettel Cyber Security</a>'}]
# [{'Value': '<a href="https://www.daviderceg.com/">David Erceg</a>'}]
# [{'Value': 's7331 with <a href="https://controlgap.com/">Control Gap</a>'}]
# [{'Value': '<a href="https://www.daviderceg.com/">David Erceg</a>'}]
# [{'Value': 'Anonymous'}]
