# %%
import json
import pandas as pd
import os
from datetime import date, datetime

# %%
# !ls
# Out:
# data  nvdcve-1.1-recent.json  pandas_env  Untitled1.ipynb  Untitled.ipynb

# %%
fn = 'nvdcve-1.1-recent.json'

# %%
with open(fn, 'r', encoding='utf-8') as rf:
    json_data = json.load(rf)

# %%
json_data
# Out:
# {'CVE_data_type': 'CVE',
#  'CVE_data_format': 'MITRE',
#  'CVE_data_version': '4.0',
#  'CVE_data_numberOfCVEs': '812',
#  'CVE_data_timestamp': '2022-04-20T10:00Z',
#  'CVE_Items': [{'cve': {'data_type': 'CVE',
#     'data_format': 'MITRE',
#     'data_version': '4.0',
#     'CVE_data_meta': {'ID': 'CVE-2022-29266',
#      'ASSIGNER': 'security@apache.org'},
#     'problemtype': {'problemtype_data': [{'description': []}]},
#     'references': {'reference_data': [{'url': 'https://lists.apache.org/thread/6qpfyxogbvn18g9xr8g218jjfjbfsbhr',
#        'name': 'https://lists.apache.org/thread/6qpfyxogbvn18g9xr8g218jjfjbfsbhr',
#        'refsource': 'MISC',
#        'tags': []},
#       {'url': 'http://www.openwall.com/lists/oss-security/2022/04/20/1',
#        'name': '[oss-security] 20220420 CVE-2022-29266: Apache APISIX: apisix/jwt-auth may leak secrets in error response',
#        'refsource': 'MLIST',
#        'tags': []}]},
#     'description': {'description_data': [{'lang': 'en',
# ...

# %%
df_recent_nvd_cves = pd.read_json(fn)

# %%
df_recent_nvd_cves
# Out:
#     CVE_data_type CVE_data_format  CVE_data_version  CVE_data_numberOfCVEs  \
# 0             CVE           MITRE                 4                    812
# 1             CVE           MITRE                 4                    812
# 2             CVE           MITRE                 4                    812
# 3             CVE           MITRE                 4                    812
# 4             CVE           MITRE                 4                    812
# ..            ...             ...               ...                    ...
# 807           CVE           MITRE                 4                    812
# 808           CVE           MITRE                 4                    812
# 809           CVE           MITRE                 4                    812
# 810           CVE           MITRE                 4                    812
# 811           CVE           MITRE                 4                    812
#
# ...

# %%
df_recent_nvd_cves.shape
# Out:
# (812, 6)

# %%
df_recent_nvd_cves.columns
# Out:
# Index(['CVE_data_type', 'CVE_data_format', 'CVE_data_version',
#        'CVE_data_numberOfCVEs', 'CVE_data_timestamp', 'CVE_Items'],
#       dtype='object')

# %%
df_recent_nvd_cves.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 812 entries, 0 to 811
# Data columns (total 6 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   CVE_data_type          812 non-null    object
#  1   CVE_data_format        812 non-null    object
#  2   CVE_data_version       812 non-null    int64
#  3   CVE_data_numberOfCVEs  812 non-null    int64
#  4   CVE_data_timestamp     812 non-null    object
#  5   CVE_Items              812 non-null    object
# dtypes: int64(2), object(4)
# memory usage: 38.2+ KB

# %%
df_recent_nvd_cves['CVE_data_type']
# Out:
# 0      CVE
# 1      CVE
# 2      CVE
# 3      CVE
# 4      CVE
#       ...
# 807    CVE
# 808    CVE
# 809    CVE
# 810    CVE
# 811    CVE
# Name: CVE_data_type, Length: 812, dtype: object

# %%
df_recent_nvd_cves_2 = pd.read_json(fn, orient='records', dtype='unicode')
df_recent_nvd_cves_2
# Out:
#     CVE_data_type CVE_data_format CVE_data_version CVE_data_numberOfCVEs  \
# 0             CVE           MITRE              4.0                   812
# 1             CVE           MITRE              4.0                   812
# 2             CVE           MITRE              4.0                   812
# 3             CVE           MITRE              4.0                   812
# 4             CVE           MITRE              4.0                   812
# ..            ...             ...              ...                   ...
# 807           CVE           MITRE              4.0                   812
# 808           CVE           MITRE              4.0                   812
# 809           CVE           MITRE              4.0                   812
# 810           CVE           MITRE              4.0                   812
# 811           CVE           MITRE              4.0                   812
#
#     CVE_data_timestamp                                          CVE_Items
# ...

# %%
df_recent_nvd_cves_2.head(5)
# Out:
#   CVE_data_type CVE_data_format CVE_data_version CVE_data_numberOfCVEs  \
# 0           CVE           MITRE              4.0                   812
# 1           CVE           MITRE              4.0                   812
# 2           CVE           MITRE              4.0                   812
# 3           CVE           MITRE              4.0                   812
# 4           CVE           MITRE              4.0                   812
#
#   CVE_data_timestamp                                          CVE_Items
# 0  2022-04-20T10:00Z  {'cve': {'data_type': 'CVE', 'data_format': 'M...
# 1  2022-04-20T10:00Z  {'cve': {'data_type': 'CVE', 'data_format': 'M...
# 2  2022-04-20T10:00Z  {'cve': {'data_type': 'CVE', 'data_format': 'M...
# 3  2022-04-20T10:00Z  {'cve': {'data_type': 'CVE', 'data_format': 'M...
# 4  2022-04-20T10:00Z  {'cve': {'data_type': 'CVE', 'data_format': 'M...

# %%
df_recent_nvd_cves_2.tail(5)
# Out:
#     CVE_data_type CVE_data_format CVE_data_version CVE_data_numberOfCVEs  \
# 807           CVE           MITRE              4.0                   812
# 808           CVE           MITRE              4.0                   812
# 809           CVE           MITRE              4.0                   812
# 810           CVE           MITRE              4.0                   812
# 811           CVE           MITRE              4.0                   812
#
#     CVE_data_timestamp                                          CVE_Items
# 807  2022-04-20T10:00Z  {'cve': {'data_type': 'CVE', 'data_format': 'M...
# 808  2022-04-20T10:00Z  {'cve': {'data_type': 'CVE', 'data_format': 'M...
# 809  2022-04-20T10:00Z  {'cve': {'data_type': 'CVE', 'data_format': 'M...
# 810  2022-04-20T10:00Z  {'cve': {'data_type': 'CVE', 'data_format': 'M...
# 811  2022-04-20T10:00Z  {'cve': {'data_type': 'CVE', 'data_format': 'M...

# %%
#pd.set_option('display.max_columns', 85)
pd.set_option('display.max_rows', 812)

# %%
df_medium_eq = df_recent_nvd_cves_2[df_recent_nvd_cves_2.impact_baseMetricV3_cvssV3_baseSeverity == 'MEDIUM']
df_low_ne = df_recent_nvd_cves_2[df_recent_nvd_cves_2.impact_baseMetricV3_cvssV3_baseSeverity != 'LOW']
df_base_score_gt_7 = df_recent_nvd_cves_2[df_recent_nvd_cves_2.impact_baseMetricV3_cvssV3_baseScore > 7.0]
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Input In [26], in <cell line: 1>()
# ----> 1 df_medium_eq = df_recent_nvd_cves_2[df_recent_nvd_cves_2.impact_baseMetricV3_cvssV3_baseSeverity == 'MEDIUM']
#       2 df_low_ne = df_recent_nvd_cves_2[df_recent_nvd_cves_2.impact_baseMetricV3_cvssV3_baseSeverity != 'LOW']
#       3 df_base_score_gt_7 = df_recent_nvd_cves_2[df_recent_nvd_cves_2.impact_baseMetricV3_cvssV3_baseScore > 7.0]
#
# File ~/pandas_dir/pandas_env/lib/python3.9/site-packages/pandas/core/generic.py:5575, in NDFrame.__getattr__(self, name)
#    5568 if (
#    5569     name not in self._internal_names_set
#    5570     and name not in self._metadata
#    5571     and name not in self._accessors
#    5572     and self._info_axis._can_hold_identifiers_and_holds_name(name)
#    5573 ):
#    5574     return self[name]
# ...

# %%
df_recent_nvd_cves_2
# Out:
#     CVE_data_type CVE_data_format CVE_data_version CVE_data_numberOfCVEs  \
# 0             CVE           MITRE              4.0                   812
# 1             CVE           MITRE              4.0                   812
# 2             CVE           MITRE              4.0                   812
# 3             CVE           MITRE              4.0                   812
# 4             CVE           MITRE              4.0                   812
# 5             CVE           MITRE              4.0                   812
# 6             CVE           MITRE              4.0                   812
# 7             CVE           MITRE              4.0                   812
# 8             CVE           MITRE              4.0                   812
# 9             CVE           MITRE              4.0                   812
# 10            CVE           MITRE              4.0                   812
# 11            CVE           MITRE              4.0                   812
# ...
