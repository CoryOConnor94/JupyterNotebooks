# %%
import datetime
import pandas as pd
import requests

# %%
todaysDate = datetime.datetime.now()
delta = datetime.timedelta(days=30)
newdate = todaysDate - delta
key = newdate.strftime("%Y-%b")

# %%
url = "https://api.msrc.microsoft.com/cvrf/v2.0/document/" + key
headers = {'Accept': 'application/json'}
response = requests.get(url, headers=headers)
json_data = response.json()

# %%
vulns = json_data.get('Vulnerability', "")[1:3]

# %%
df_vulns = pd.json_normalize(data=vulns, sep="_")

# %%
df_revisionHistory = pd.json_normalize(data=vulns, record_path=['RevisionHistory'], meta=["CVE"], sep="_")
df_revisionHistory = df_revisionHistory.add_prefix('RevisionHistory_')

# %%
df_CVSSScore = pd.json_normalize(data=vulns, record_path=['CVSSScoreSets'], meta=["CVE"], sep="_")
df_CVSSScore = df_CVSSScore.add_prefix('CVSSScoreSets_')
df_notes = pd.json_normalize(data=vulns, record_path=['Notes'], meta=["CVE"], sep="_")
df_notes = df_notes.add_prefix('Notes_')
df_ProductStatuses = pd.json_normalize(data=vulns, record_path=['ProductStatuses'], meta=["CVE"], sep="_")
df_ProductStatuses = df_ProductStatuses.add_prefix('ProductStatuses_')
df_Threats = pd.json_normalize(data=vulns, record_path=['Threats'], meta=["CVE"], sep="_")
df_Threats = df_Threats.add_prefix('Threats_')
df_Remediations = pd.json_normalize(data=vulns, record_path=['Remediations'], meta=["CVE"], sep="_").explode('ProductID')
df_Remediations = df_Remediations.add_prefix('Remediations_')

# %%
product_id_list_list = df_CVSSScore.CVSSScoreSets_ProductID.tolist()
product_id_list = ["; ".join(prod_id) for prod_id in product_id_list_list]
df_CVSSScore.CVSSScoreSets_ProductID = product_id_list

df_Threats.Threats_ProductID = df_Threats.Threats_ProductID.fillna('').apply(list)
threats_product_id_list_list = df_Threats.Threats_ProductID.tolist()
threats_product_id_list = ["; ".join(prod_id) for prod_id in threats_product_id_list_list]
df_Threats.Threats_ProductID = threats_product_id_list

# %%
df_vulns = df_vulns.merge(df_CVSSScore, left_on="CVE", right_on="CVSSScoreSets_CVE", how='left')
df_vulns.drop('CVSSScoreSets', inplace=True, axis=1)
df_vulns.shape
# Out:
# (50, 16)

# %%
df_vulns = df_vulns.merge(df_revisionHistory, left_on="CVE", right_on="RevisionHistory_CVE", how='left')
df_vulns.drop('RevisionHistory', inplace=True, axis=1)
df_vulns.shape
# Out:
# (50, 19)

# %%
df_vulns = df_vulns.merge(df_ProductStatuses, left_on="CVE", right_on="ProductStatuses_CVE", how='left')
df_vulns.drop('ProductStatuses', inplace=True, axis=1)
df_vulns.shape
# Out:
# (50, 21)

# %%
df_vulns.shape
# Out:
# (50, 21)

# %%
df_Threats.shape
# Out:
# (102, 5)

# %%
inner_join = pd.merge(left=df_vulns, right=df_Threats, left_on ="CVSSScoreSets_ProductID", right_on="Threats_ProductID")
inner_join.shape
# Out:
# (128, 26)

# %%
df_vulns.head(5)
# Out:
#                                                Notes  DiscoveryDateSpecified  \
# 0  [{'Title': 'Description', 'Type': 2, 'Ordinal'...                   False
# 1  [{'Title': 'Description', 'Type': 2, 'Ordinal'...                   False
# 2  [{'Title': 'Description', 'Type': 2, 'Ordinal'...                   False
# 3  [{'Title': 'Description', 'Type': 2, 'Ordinal'...                   False
# 4  [{'Title': 'Description', 'Type': 2, 'Ordinal'...                   False
#
#    ReleaseDateSpecified             CVE  \
# 0                 False  CVE-2022-22009
# 1                 False  CVE-2022-22009
# 2                 False  CVE-2022-22009
# 3                 False  CVE-2022-22009
# 4                 False  CVE-2022-22009
#
#                                              Threats  \
# 0  [{'Description': {'Value': 'Remote Code Execut...
# 1  [{'Description': {'Value': 'Remote Code Execut...
# 2  [{'Description': {'Value': 'Remote Code Execut...
# 3  [{'Description': {'Value': 'Remote Code Execut...
# 4  [{'Description': {'Value': 'Remote Code Execut...
#
#                                         Remediations  \
# 0  [{'Description': {'Value': '5012599'}, 'URL': ...
# 1  [{'Description': {'Value': '5012599'}, 'URL': ...
# 2  [{'Description': {'Value': '5012599'}, 'URL': ...
# 3  [{'Description': {'Value': '5012599'}, 'URL': ...
# 4  [{'Description': {'Value': '5012599'}, 'URL': ...
#
#                                      Acknowledgments Ordinal  \
# 0  [{'Name': [{'Value': '<a href="https://twitter...      52
# 1  [{'Name': [{'Value': '<a href="https://twitter...      52
# 2  [{'Name': [{'Value': '<a href="https://twitter...      52
# 3  [{'Name': [{'Value': '<a href="https://twitter...      52
# 4  [{'Name': [{'Value': '<a href="https://twitter...      52
#
#                                          Title_Value  CVSSScoreSets_BaseScore  \
# 0  Windows Hyper-V Remote Code Execution Vulnerab...                      7.8
# 1  Windows Hyper-V Remote Code Execution Vulnerab...                      7.8
# 2  Windows Hyper-V Remote Code Execution Vulnerab...                      7.8
# 3  Windows Hyper-V Remote Code Execution Vulnerab...                      7.8
# 4  Windows Hyper-V Remote Code Execution Vulnerab...                      7.8
#
#    ...                               CVSSScoreSets_Vector  \
# 0  ...  CVSS:3.1/AV:L/AC:H/PR:L/UI:N/S:C/C:H/I:H/A:H/E...
# 1  ...  CVSS:3.1/AV:L/AC:H/PR:L/UI:N/S:C/C:H/I:H/A:H/E...
# 2  ...  CVSS:3.1/AV:L/AC:H/PR:L/UI:N/S:C/C:H/I:H/A:H/E...
# 3  ...  CVSS:3.1/AV:L/AC:H/PR:L/UI:N/S:C/C:H/I:H/A:H/E...
# 4  ...  CVSS:3.1/AV:L/AC:H/PR:L/UI:N/S:C/C:H/I:H/A:H/E...
#
#   CVSSScoreSets_ProductID CVSSScoreSets_CVE RevisionHistory_Number  \
# 0                   11896    CVE-2022-22009                    1.0
# 1                   11923    CVE-2022-22009                    1.0
# 2                   11924    CVE-2022-22009                    1.0
# 3                   11800    CVE-2022-22009                    1.0
# 4                   11803    CVE-2022-22009                    1.0
#
#   RevisionHistory_Date RevisionHistory_Description_Value RevisionHistory_CVE  \
# 0  2022-04-12T07:00:00   <p>Information published.</p>\n      CVE-2022-22009
# 1  2022-04-12T07:00:00   <p>Information published.</p>\n      CVE-2022-22009
# 2  2022-04-12T07:00:00   <p>Information published.</p>\n      CVE-2022-22009
# 3  2022-04-12T07:00:00   <p>Information published.</p>\n      CVE-2022-22009
# 4  2022-04-12T07:00:00   <p>Information published.</p>\n      CVE-2022-22009
#
#                            ProductStatuses_ProductID ProductStatuses_Type  \
# 0  [11896, 11923, 11924, 11800, 11803, 11926, 11931]                    3
# 1  [11896, 11923, 11924, 11800, 11803, 11926, 11931]                    3
# 2  [11896, 11923, 11924, 11800, 11803, 11926, 11931]                    3
# 3  [11896, 11923, 11924, 11800, 11803, 11926, 11931]                    3
# 4  [11896, 11923, 11924, 11800, 11803, 11926, 11931]                    3
#
#    ProductStatuses_CVE
# 0       CVE-2022-22009
# 1       CVE-2022-22009
# 2       CVE-2022-22009
# 3       CVE-2022-22009
# 4       CVE-2022-22009
#
# [5 rows x 21 columns]

# %%
df_Threats.head(5)
# Out:
#   Threats_ProductID  Threats_Type  Threats_DateSpecified  \
# 0             11896             0                  False
# 1             11923             0                  False
# 2             11924             0                  False
# 3             11800             0                  False
# 4             11803             0                  False
#
#   Threats_Description_Value     Threats_CVE
# 0     Remote Code Execution  CVE-2022-22009
# 1     Remote Code Execution  CVE-2022-22009
# 2     Remote Code Execution  CVE-2022-22009
# 3     Remote Code Execution  CVE-2022-22009
# 4     Remote Code Execution  CVE-2022-22009

# %%
inner_join = pd.merge(left=df_vulns, right=df_Threats, left_on =["CVSSScoreSets_ProductID", "CVSSScoreSets_CVE"], right_on=["Threats_ProductID", "Threats_CVE"])
inner_join.drop('Threats', inplace=True, axis=1)
inner_join.shape
# Out:
# (100, 25)

# %%
df_vulns.drop('Notes', inplace=True, axis=1)
inner_join.head(5)
# Out:
#                                                Notes  DiscoveryDateSpecified  \
# 0  [{'Title': 'Description', 'Type': 2, 'Ordinal'...                   False
# 1  [{'Title': 'Description', 'Type': 2, 'Ordinal'...                   False
# 2  [{'Title': 'Description', 'Type': 2, 'Ordinal'...                   False
# 3  [{'Title': 'Description', 'Type': 2, 'Ordinal'...                   False
# 4  [{'Title': 'Description', 'Type': 2, 'Ordinal'...                   False
#
#    ReleaseDateSpecified             CVE  \
# 0                 False  CVE-2022-22009
# 1                 False  CVE-2022-22009
# 2                 False  CVE-2022-22009
# 3                 False  CVE-2022-22009
# 4                 False  CVE-2022-22009
#
#                                         Remediations  \
# 0  [{'Description': {'Value': '5012599'}, 'URL': ...
# 1  [{'Description': {'Value': '5012599'}, 'URL': ...
# 2  [{'Description': {'Value': '5012599'}, 'URL': ...
# 3  [{'Description': {'Value': '5012599'}, 'URL': ...
# 4  [{'Description': {'Value': '5012599'}, 'URL': ...
#
#                                      Acknowledgments Ordinal  \
# 0  [{'Name': [{'Value': '<a href="https://twitter...      52
# 1  [{'Name': [{'Value': '<a href="https://twitter...      52
# 2  [{'Name': [{'Value': '<a href="https://twitter...      52
# 3  [{'Name': [{'Value': '<a href="https://twitter...      52
# 4  [{'Name': [{'Value': '<a href="https://twitter...      52
#
#                                          Title_Value  CVSSScoreSets_BaseScore  \
# 0  Windows Hyper-V Remote Code Execution Vulnerab...                      7.8
# 1  Windows Hyper-V Remote Code Execution Vulnerab...                      7.8
# 2  Windows Hyper-V Remote Code Execution Vulnerab...                      7.8
# 3  Windows Hyper-V Remote Code Execution Vulnerab...                      7.8
# 4  Windows Hyper-V Remote Code Execution Vulnerab...                      7.8
#
#    CVSSScoreSets_TemporalScore  ... RevisionHistory_Description_Value  \
# 0                          6.8  ...   <p>Information published.</p>\n
# 1                          6.8  ...   <p>Information published.</p>\n
# 2                          6.8  ...   <p>Information published.</p>\n
# 3                          6.8  ...   <p>Information published.</p>\n
# 4                          6.8  ...   <p>Information published.</p>\n
#
#   RevisionHistory_CVE                          ProductStatuses_ProductID  \
# 0      CVE-2022-22009  [11896, 11923, 11924, 11800, 11803, 11926, 11931]
# 1      CVE-2022-22009  [11896, 11923, 11924, 11800, 11803, 11926, 11931]
# 2      CVE-2022-22009  [11896, 11923, 11924, 11800, 11803, 11926, 11931]
# 3      CVE-2022-22009  [11896, 11923, 11924, 11800, 11803, 11926, 11931]
# 4      CVE-2022-22009  [11896, 11923, 11924, 11800, 11803, 11926, 11931]
#
#   ProductStatuses_Type ProductStatuses_CVE Threats_ProductID Threats_Type  \
# 0                    3      CVE-2022-22009             11896            0
# 1                    3      CVE-2022-22009             11896            3
# 2                    3      CVE-2022-22009             11923            0
# 3                    3      CVE-2022-22009             11923            3
# 4                    3      CVE-2022-22009             11924            0
#
#   Threats_DateSpecified  Threats_Description_Value     Threats_CVE
# 0                 False      Remote Code Execution  CVE-2022-22009
# 1                 False                  Important  CVE-2022-22009
# 2                 False      Remote Code Execution  CVE-2022-22009
# 3                 False                  Important  CVE-2022-22009
# 4                 False      Remote Code Execution  CVE-2022-22009
#
# [5 rows x 25 columns]

# %%
df_vulns['CVSSScoreSets_ProductID'].isin(df_Threats['Threats_ProductID']).value_counts()
# Out:
# True    50
# Name: CVSSScoreSets_ProductID, dtype: int64

# %%
df_Remediations.shape
# Out:
# (162, 11)

# %%
df_Remediations.head(5)
# Out:
#                                     Remediations_URL  \
# 0  https://catalog.update.microsoft.com/v7/site/S...
# 1         https://support.microsoft.com/help/5012599
# 1         https://support.microsoft.com/help/5012599
# 1         https://support.microsoft.com/help/5012599
# 1         https://support.microsoft.com/help/5012599
#
#   Remediations_Supercedence Remediations_ProductID  Remediations_Type  \
# 0                   5011487                  11896                  2
# 1                       NaN                  11896                  5
# 1                       NaN                  11800                  5
# 1                       NaN                  11803                  5
# 1                       NaN                  11931                  5
#
#    Remediations_DateSpecified Remediations_AffectedFiles Remediations_SubType  \
# 0                       False                         []      Security Update
# 1                       False                         []                  NaN
# 1                       False                         []                  NaN
# 1                       False                         []                  NaN
# 1                       False                         []                  NaN
#
#   Remediations_FixedBuild Remediations_Description_Value  \
# 0         10.0.19043.1645                        5012599
# 1                     NaN                        5012599
# 1                     NaN                        5012599
# 1                     NaN                        5012599
# 1                     NaN                        5012599
#
#   Remediations_RestartRequired_Value Remediations_CVE
# 0                                Yes   CVE-2022-22009
# 1                                NaN   CVE-2022-22009
# 1                                NaN   CVE-2022-22009
# 1                                NaN   CVE-2022-22009
# 1                                NaN   CVE-2022-22009

# %%
inner_join.head(5)
# Out:
#                                                Notes  DiscoveryDateSpecified  \
# 0  [{'Title': 'Description', 'Type': 2, 'Ordinal'...                   False
# 1  [{'Title': 'Description', 'Type': 2, 'Ordinal'...                   False
# 2  [{'Title': 'Description', 'Type': 2, 'Ordinal'...                   False
# 3  [{'Title': 'Description', 'Type': 2, 'Ordinal'...                   False
# 4  [{'Title': 'Description', 'Type': 2, 'Ordinal'...                   False
#
#    ReleaseDateSpecified             CVE  \
# 0                 False  CVE-2022-22009
# 1                 False  CVE-2022-22009
# 2                 False  CVE-2022-22009
# 3                 False  CVE-2022-22009
# 4                 False  CVE-2022-22009
#
#                                         Remediations  \
# 0  [{'Description': {'Value': '5012599'}, 'URL': ...
# 1  [{'Description': {'Value': '5012599'}, 'URL': ...
# 2  [{'Description': {'Value': '5012599'}, 'URL': ...
# 3  [{'Description': {'Value': '5012599'}, 'URL': ...
# 4  [{'Description': {'Value': '5012599'}, 'URL': ...
#
#                                      Acknowledgments Ordinal  \
# 0  [{'Name': [{'Value': '<a href="https://twitter...      52
# 1  [{'Name': [{'Value': '<a href="https://twitter...      52
# 2  [{'Name': [{'Value': '<a href="https://twitter...      52
# 3  [{'Name': [{'Value': '<a href="https://twitter...      52
# 4  [{'Name': [{'Value': '<a href="https://twitter...      52
#
#                                          Title_Value  CVSSScoreSets_BaseScore  \
# 0  Windows Hyper-V Remote Code Execution Vulnerab...                      7.8
# 1  Windows Hyper-V Remote Code Execution Vulnerab...                      7.8
# 2  Windows Hyper-V Remote Code Execution Vulnerab...                      7.8
# 3  Windows Hyper-V Remote Code Execution Vulnerab...                      7.8
# 4  Windows Hyper-V Remote Code Execution Vulnerab...                      7.8
#
#    CVSSScoreSets_TemporalScore  ... RevisionHistory_Description_Value  \
# 0                          6.8  ...   <p>Information published.</p>\n
# 1                          6.8  ...   <p>Information published.</p>\n
# 2                          6.8  ...   <p>Information published.</p>\n
# 3                          6.8  ...   <p>Information published.</p>\n
# 4                          6.8  ...   <p>Information published.</p>\n
#
#   RevisionHistory_CVE                          ProductStatuses_ProductID  \
# 0      CVE-2022-22009  [11896, 11923, 11924, 11800, 11803, 11926, 11931]
# 1      CVE-2022-22009  [11896, 11923, 11924, 11800, 11803, 11926, 11931]
# 2      CVE-2022-22009  [11896, 11923, 11924, 11800, 11803, 11926, 11931]
# 3      CVE-2022-22009  [11896, 11923, 11924, 11800, 11803, 11926, 11931]
# 4      CVE-2022-22009  [11896, 11923, 11924, 11800, 11803, 11926, 11931]
#
#   ProductStatuses_Type ProductStatuses_CVE Threats_ProductID Threats_Type  \
# 0                    3      CVE-2022-22009             11896            0
# 1                    3      CVE-2022-22009             11896            3
# 2                    3      CVE-2022-22009             11923            0
# 3                    3      CVE-2022-22009             11923            3
# 4                    3      CVE-2022-22009             11924            0
#
#   Threats_DateSpecified  Threats_Description_Value     Threats_CVE
# 0                 False      Remote Code Execution  CVE-2022-22009
# 1                 False                  Important  CVE-2022-22009
# 2                 False      Remote Code Execution  CVE-2022-22009
# 3                 False                  Important  CVE-2022-22009
# 4                 False      Remote Code Execution  CVE-2022-22009
#
# [5 rows x 25 columns]

# %%
inner_join = pd.merge(left=inner_join,right=df_Remediations, left_on="Threats_ProductID", right_on="Remediations_ProductID")
inner_join.shape
# Out:
# (410, 36)

# %%
inner_join = pd.merge(left=inner_join, right=df_Remediations, left_on=["Threats_ProductID", "Threats_CVE"], right_on=["Remediations_ProductID", "Remediations_CVE"])
inner_join.drop('Remediations', inplace=True, axis=1)
inner_join.shape
